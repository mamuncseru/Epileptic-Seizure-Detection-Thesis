# %% [markdown]
# ## Investigating the Impact of Residual Connection to Convolutional Layer on EEG Classification Performance

# %% [markdown]
# ### Experiment Summary:
#
# **This experiment aims to explore the influence of residual connection with convolutional layers on the performance of EEG classification models. We investigate the relationship between the number of convolutional layers and the resulting accuracy.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %mkdir /content/drive/MyDrive/ED_Experiments
# %mkdir /content/drive/MyDrive/ED_Experiments/ED_CNN_E13

# %%
# %mkdir /content/drive/MyDrive/ED_experiments/SeizureVsEyeOpen

# %%
# %cd /content/drive/MyDrive/ED_experiments/SeizureVsEyeOpen
# %ls
# Out:
# /content/drive/MyDrive/ED_experiments/SeizureVsEyeOpen

# %% [markdown]
# ## Import libraries

# %%
import sys
import os
import logging


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, StratifiedKFold

from tqdm import tqdm

import keras
from keras.layers import Dense, Convolution1D, MaxPool1D, Flatten, Dropout
from keras.layers import Input, LSTM
from keras.layers import BatchNormalization
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import metrics

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
## seed
np.random.seed(2023)

# %% [markdown]
# ### Reading CSV data

# %%
raw_data = pd.read_csv('https://raw.githubusercontent.com/mamuncseru/analysis_on_epileptic_seizure_bonn_dataset/main/Epileptic%20Seizure%20Recognition.csv')
raw_data.shape
# Out:
# (11500, 180)

# %%
raw_data
# Out:
#           Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  \
# 0      X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17
# 1      X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164
# 2         X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57
# 3       X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82
# 4       X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 11495  X22.V1.114  -22  -22  -23  -26  -36  -42  -45  -42  -45  ...    15
# 11496  X19.V1.354  -47  -11   28   77  141  211  246  240  193  ...   -65
# 11497    X8.V1.28   14    6  -13  -16   10   26   27   -9    4  ...   -65
# 11498  X10.V1.932  -40  -25   -9  -12   -2   12    7   19   22  ...   121
# 11499  X16.V1.210   29   41   57   72   74   62   54   43   31  ...   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# 0       -15   -31   -77  -103  -127  -116   -83   -51  4
# 1       150   146   152   157   156   154   143   129  1
# 2        64    48    19   -12   -30   -35   -35   -36  5
# 3       -81   -80   -77   -85   -77   -72   -69   -65  5
# 4         2   -12   -32   -41   -65   -83   -89   -73  5
# ...     ...   ...   ...   ...   ...   ...   ...   ... ..
# 11495    16    12     5    -1   -18   -37   -47   -48  2
# 11496   -33    -7    14    27    48    77   117   170  1
# 11497   -48   -61   -62   -67   -30    -2    -1    -8  5
# 11498   135   148   143   116    86    68    59    55  3
# 11499   -25    -4     2     5     4    -2     2    20  4
#
# [11500 rows x 180 columns]

# %%
raw_data.values.shape
# Out:
# (11500, 180)

# %%
data = raw_data.values # converted to an numpy array
data = data[:, 1:] # discarding the Unnamed Column
data.shape
# Out:
# (11500, 179)

# %%
# let's see how it looks like
data
# Out:
# array([[135, 190, 229, ..., -83, -51, 4],
#        [386, 382, 356, ..., 143, 129, 1],
#        [-32, -39, -47, ..., -35, -36, 5],
#        ...,
#        [14, 6, -13, ..., -1, -8, 5],
#        [-40, -25, -9, ..., 59, 55, 3],
#        [29, 41, 57, ..., 2, 20, 4]], dtype=object)

# %%
# let's see the type
type(data)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Classifying data categories as it mentioned in the paper

# %%
df_1 = data[data[:, -1] == 1].astype(int) # seizure
df_2 = data[data[:, -1] == 2].astype(int)
df_3 = data[data[:, -1] == 3].astype(int)
df_4 = data[data[:, -1] == 4].astype(int)
df_5 = data[data[:, -1] == 5].astype(int)

# let's print the shape of each category
print(df_1.shape)
print(df_2.shape)
print(df_3.shape)
print(df_4.shape)
print(df_5.shape)
# Out:
# (2300, 179)
# (2300, 179)
# (2300, 179)
# (2300, 179)
# (2300, 179)

# %% [markdown]
# ## Let's plot some random data points from every category

# %%
def visualize_eeg(number_of_datapoints):
    for i in (np.random.randint(0, 2300, number_of_datapoints)):
        plt.plot(df_1[i, :], 'r-', label='df_1')
        plt.plot(df_5[i, :], 'm-', label='df_5')
        plt.legend()
        plt.title(f'Eye open vs Seizure data visualizing {i} th data point')
        plt.xlabel('time')
        plt.ylabel('aplitude(uV)')
        plt.show()

# %% [markdown]
# ### Visualizing all categories in single figure

# %%
### all categories
visualize_eeg(5)

# %% [markdown]
# ## Converting data into integer and making the data into seizure and non-seizure cateogry

# %%
data = np.concatenate((df_1, df_5))

# %% [markdown]
# ## Plot functions

# %% [markdown]
# ### function to plot loss curve of the
# - (training and validation loss) and
# - (training and validation accuracy)

# %%
def plot_loss_accuracy(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(14, 6))

    ax[0].plot(history.history['loss'], 'b-')
    ax[0].plot(history.history['val_loss'], 'r-')
    ax[0].legend(['train_loss', 'val_loss'])
    ax[0].set_title('Loss curve')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss %')

    ax[1].plot(history.history['accuracy'], 'b-')
    ax[1].plot(history.history['val_accuracy'], 'r-')
    ax[1].legend(['train_accuracy', 'val_accuracy'])
    ax[1].set_title('Accuracy curve')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('accuracy %')

    plt.suptitle(title)
    plt.savefig(title + '_loss_accuracy.png')

    plt.show()

# %%
def plot_precision_recall(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(14, 6))

    ax[0].plot(history.history['precision'], 'b-')
    ax[0].plot(history.history['val_precision'], 'r-')
    ax[0].legend(['train_precision', 'val_precision'])
    ax[0].set_title('precision curve')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Precision %')

    ax[1].plot(history.history['recall'], 'b-')
    ax[1].plot(history.history['val_recall'], 'r-')
    ax[1].legend(['train_recall', 'val_recall'])
    ax[1].set_title('recall curve')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Recall %')

    plt.suptitle(title)
    plt.savefig(title + '_precision_recall.png')

    plt.show()

# %%
# Initialize StratifiedKFold with 5 folds
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=2023)

# %%
def input_output_data(data, random_state=2023):
    data[:, -1] = np.where(data[:, -1] != 1, 0, data[:, -1])

    X = data[:, :-1]
    y = data[:, -1]

    return X, y

X, y = input_output_data(data)

# %%
X.shape
# Out:
# (4600, 178)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
def process_input(X, y, train_index, val_index):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    X_train = np.expand_dims(X_train, axis=2)
    X_val = np.expand_dims(X_val, axis=2)

    input_shape = (X_train.shape[1], 1)

    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')


    return X_train, X_val, y_train, y_val, input_shape

# %% [markdown]
# ## Logger setup

# %%
import absl.logging
import sys
import logging
absl.logging.set_verbosity(absl.logging.ERROR)
absl.logging.set_verbosity(absl.logging.INFO)

# %%
def init_logger(log_file, log_level=logging.INFO, stdout=True):
    logger = logging.getLogger()
    logger.setLevel(log_level)

    formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')

    file_handler = logging.FileHandler(log_file, mode='w')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    if stdout:
        console_handler = logging.StreamHandler(sys.stdout)
        console_handler.setFormatter(formatter)
        logger.addHandler(console_handler)

    return logger

# %% [markdown]
# ## Let's experiment with the Residual Connection

# %%
def residual_block(x, filters, kernel_size, padding='same', activation='relu'):
    shortcut = x
    x = layers.Conv1D(filters=filters, kernel_size=kernel_size, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(activation)(x)
    x = layers.Conv1D(filters=filters, kernel_size=kernel_size, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([shortcut, x])
    x = layers.Activation(activation)(x)
    return x

def create_residual_eeg_model(input_shape):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv1D(filters=128, kernel_size=5, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=128, kernel_size=5)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=256, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=256, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=512, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=512, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=1024, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=1024, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=2048, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=2048, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.GlobalAveragePooling1D()(x)  # Replace Flatten layer with GlobalAveragePooling1D
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Perform cross-validation
fold_accuracy = []
fold_precision = []
fold_recall = []
fold_f1score = []
fold = 1

for train_index, val_index in skf.split(X, y):
    X_train, X_val, y_train, y_val, input_shape = process_input(X, y, train_index, val_index)
    print('X_train: ', X_train.shape)
    print('X_val: ', X_val.shape)
    print('y_train: ', y_train.shape)
    print('y_val: ', y_val.shape)


    # model = eegClassifier(input_shape)
    model = create_residual_eeg_model(input_shape)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',
                                                                         tf.keras.metrics.Precision(name='precision'),
                                                                         tf.keras.metrics.Recall(name='recall')])
    log_file = f"model_fold_{fold}.log"
    model_name = f"model_fold_{fold}.h5"

    # Clear existing log handlers and close log files
    root_logger = logging.getLogger()
    for handler in root_logger.handlers:
        handler.close()
    root_logger.handlers.clear()

    # Create a separate log file for each model
    logger = init_logger(log_file, stdout=False)


    logger.info(f"\n\n---- fold = {fold} -------\n")
    print(f"\n\n---- fold = {fold} ------\n")

    # Define the checkpoint callback to save the best model
    checkpoint = ModelCheckpoint(model_name, monitor='val_accuracy', save_best_only=True, mode='max', save_format="h5")

    # Train the model and capture the history
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,
                        callbacks=[checkpoint])

    # Log loss and accuracy
    for i, (loss, accuracy, precision, recall) in enumerate(zip(history.history['loss'],
                                                                history.history['accuracy'],
                                                                history.history['precision'],
                                                                history.history['recall'])):
        logger.info(f"Epoch {i+1} - Loss: {loss} - Accuracy: {accuracy} - Precision: {precision} - Recall: {recall}")

    for i, (val_loss, val_accuracy, val_precision, val_recall) in enumerate(zip(history.history['val_loss'],
                                                                                history.history['val_accuracy'],
                                                                                history.history['val_precision'],
                                                                                history.history['val_recall'])):
        logger.info(f"Epoch {i+1} - Validation Loss: {val_loss} - Validation Accuracy: {val_accuracy}")


    # Evaluate the model
    best_model_path = model_name
    best_model = tf.keras.models.load_model(best_model_path)
    loss_scale_optimizer, accuracy, precision, recall = best_model.evaluate(X_val, y_val)
    fold_accuracy.append(accuracy)
    fold_precision.append(precision)
    fold_recall.append(recall)

    # Log fold accuracy
    logger.info(f"model_Fold = {fold} accuracy: {accuracy}")
    logger.info(f"model_Fold = {fold} precision: {precision}")
    logger.info(f"model_Fold = {fold} recall: {recall}")


    print(f"model_Fold = {fold} accuracy: {accuracy}")
    print(f"model_Fold = {fold} precision: {precision}")
    print(f"model_Fold = {fold} recall: {recall}")
    print(f"model_Fold = {fold} f1_score: {2*(precision*recall) / (precision + recall)}")

    plot_loss_accuracy(history, f"model_fold_{fold}")
    plot_precision_recall(history, f"model_fold_{fold}")
    # plot_accuracy(history)

    fold += 1

# Calculate the average accuracy across all folds
mean_accuracy = np.mean(fold_accuracy)
mean_precision = np.mean(fold_precision)
mean_recall = np.mean(fold_recall)
mean_f1_score = 2 * (mean_precision * mean_recall) / (mean_precision + mean_recall)

print("Mean Accuracy:", mean_accuracy)
print("Mean Precision:", mean_precision)
print("Mean Recall:", mean_recall)
print("Mean F1_Score:", mean_f1_score)
# Out:
# X_train:  (3680, 178, 1)
# X_val:  (920, 178, 1)
# y_train:  (3680,)
# y_val:  (920,)
#
#
# ---- fold = 1 ------
#
# Epoch 1/100
# 115/115 [==============================] - 32s 166ms/step - loss: 0.1230 - accuracy: 0.9582 - precision: 0.9657 - recall: 0.9500 - val_loss: 0.8724 - val_accuracy: 0.8554 - val_precision: 0.7757 - val_recall: 1.0000
# Epoch 2/100
# 115/115 [==============================] - 15s 130ms/step - loss: 0.0893 - accuracy: 0.9734 - precision: 0.9775 - recall: 0.9690 - val_loss: 0.0181 - val_accuracy: 0.9924 - val_precision: 0.9913 - val_recall: 0.9935
# Epoch 3/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.0744 - accuracy: 0.9742 - precision: 0.9765 - recall: 0.9717 - val_loss: 0.0092 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 4/100
# 115/115 [==============================] - 9s 78ms/step - loss: 0.0554 - accuracy: 0.9815 - precision: 0.9836 - recall: 0.9793 - val_loss: 0.0582 - val_accuracy: 0.9761 - val_precision: 0.9544 - val_recall: 1.0000
# Epoch 5/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0504 - accuracy: 0.9851 - precision: 0.9885 - recall: 0.9815 - val_loss: 0.0875 - val_accuracy: 0.9609 - val_precision: 0.9274 - val_recall: 1.0000
# Epoch 6/100
# 115/115 [==============================] - 9s 77ms/step - loss: 0.0437 - accuracy: 0.9859 - precision: 0.9896 - recall: 0.9821 - val_loss: 0.0092 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 7/100
# 115/115 [==============================] - 9s 78ms/step - loss: 0.0420 - accuracy: 0.9859 - precision: 0.9864 - recall: 0.9853 - val_loss: 0.0101 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 8/100
# 115/115 [==============================] - 9s 78ms/step - loss: 0.0367 - accuracy: 0.9870 - precision: 0.9870 - recall: 0.9870 - val_loss: 0.1743 - val_accuracy: 0.9913 - val_precision: 0.9850 - val_recall: 0.9978
# Epoch 9/100
# 115/115 [==============================] - 9s 78ms/step - loss: 0.0375 - accuracy: 0.9864 - precision: 0.9875 - recall: 0.9853 - val_loss: 0.1543 - val_accuracy: 0.9772 - val_precision: 1.0000 - val_recall: 0.9543
# Epoch 10/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0342 - accuracy: 0.9905 - precision: 0.9902 - recall: 0.9908 - val_loss: 0.2999 - val_accuracy: 0.9076 - val_precision: 0.8440 - val_recall: 1.0000
# Epoch 11/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0520 - accuracy: 0.9840 - precision: 0.9879 - recall: 0.9799 - val_loss: 0.0208 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 12/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0228 - accuracy: 0.9935 - precision: 0.9962 - recall: 0.9908 - val_loss: 0.0095 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 13/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0274 - accuracy: 0.9918 - precision: 0.9940 - recall: 0.9897 - val_loss: 0.1910 - val_accuracy: 0.9478 - val_precision: 0.9071 - val_recall: 0.9978
# Epoch 14/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0260 - accuracy: 0.9921 - precision: 0.9929 - recall: 0.9913 - val_loss: 0.0074 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch
100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0070 - accuracy: 0.9984 - precision: 0.9978 - recall: 0.9989 - val_loss: 0.0039 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 84/100
# 115/115 [==============================] - 9s 82ms/step - loss: 2.8820e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 85/100
# 115/115 [==============================] - 9s 81ms/step - loss: 9.2308e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 86/100
# 115/115 [==============================] - 9s 81ms/step - loss: 5.0876e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 87/100
# 115/115 [==============================] - 9s 81ms/step - loss: 5.7092e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 88/100
# 115/115 [==============================] - 9s 81ms/step - loss: 1.9030e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 89/100
# 115/115 [==============================] - 9s 81ms/step - loss: 2.0209e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 90/100
# 115/115 [==============================] - 9s 82ms/step - loss: 1.2077e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 91/100
# 115/115 [==============================] - 9s 82ms/step - loss: 9.3360e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 92/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0359 - accuracy: 0.9910 - precision: 0.9918 - recall: 0.9902 - val_loss: 0.0081 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 93/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0028 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0033 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 94/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0011 - accuracy: 0.9995 - precision: 0.9989 - recall: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 95/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0062 - accuracy: 0.9973 - precision: 0.9967 - recall: 0.9978 - val_loss: 0.0058 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 96/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0029 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0079 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 97/100
# 115/115 [==============================] - 9s 81ms/step - loss: 1.8386e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 98/100
# 115/115 [==============================] - 9s 81ms/step - loss: 2.9416e-04 - accuracy: 0.9997 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 99/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0040 - accuracy: 0.9984 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0085 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 100/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0030 - accuracy: 0.9989 - precision: 0.9995 - recall: 0.9984 - val_loss: 0.0051 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0021 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# model_Fold = 1 accuracy: 1.0
# model_Fold = 1 precision: 1.0
# model_Fold = 1 recall: 1.0
# model_Fold = 1 f1_score: 1.0
# X_train:  (3680, 178, 1)
# X_val:  (920, 178, 1)
# y_train:  (3680,)
# y_val:  (920,)
#
#
# ---- fold = 2 ------
#
# Epoch 1/100
# 115/115 [==============================] - 34s 174ms/step - loss: 0.1114 - accuracy: 0.9628 - precision: 0.9681 - recall: 0.9571 - val_loss: 0.3299 - val_accuracy: 0.9489 - val_precision: 0.9105 - val_recall: 0.9957
# Epoch 2/100
# 115/115 [==============================] - 15s 134ms/step - loss: 0.0802 - accuracy: 0.9723 - precision: 0.9733 - recall: 0.9712 - val_loss: 0.0782 - val_accuracy: 0.9848 - val_precision: 0.9705 - val_recall: 1.0000
# Epoch 3/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0704 - accuracy: 0.9750 - precision: 0.9807 - recall: 0.9690 - val_loss: 0.1669 - val_accuracy: 0.9120 - val_precision: 0.8503 - val_recall: 1.0000
# Epoch 4/100
# 115/115 [==============================] - 21s 182ms/step - loss: 0.0607 - accuracy: 0.9818 - precision: 0.9815 - recall: 0.9821 - val_loss: 0.0348 - val_accuracy: 0.9902 - val_precision: 1.0000 - val_recall: 0.9804
# Epoch 5/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0599 - accuracy: 0.9812 - precision: 0.9836 - recall: 0.9788 - val_loss: 0.1729 - val_accuracy: 0.9652 - val_precision: 1.0000 - val_recall: 0.9304
# Epoch 6/100
# 115/115 [==============================] - 15s 129ms/step - loss: 0.0578 - accuracy: 0.9807 - precision: 0.9815 - recall: 0.9799 - val_loss: 0.0233 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 7/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0321 - accuracy: 0.9902 - precision: 0.9913 - recall: 0.9891 - val_loss: 0.0150 - val_accuracy: 0.9935 - val_precision: 0.9956 - val_recall: 0.9913
# Epoch 8/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0423 - accuracy: 0.9853 - precision: 0.9885 - recall: 0.9821 - val_loss: 0.1039 - val_accuracy: 0.9826 - val_precision: 0.9664 - val_recall: 1.0000
# Epoch 9/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0473 - accuracy: 0.9853 - precision: 0.9864 - recall: 0.9842 - val_loss: 0.0564 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9848
# Epoch 10/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0411 - accuracy: 0.9883 - precision: 0.9902 - recall: 0.9864 - val_loss: 0.0364 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9848
# Epoch 11/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0306 - accuracy: 0.9905 - precision: 0.9913 - recall: 0.9897 - val_loss: 0.0141 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 12/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0223 - accuracy: 0.9935 - precision: 0.9951 - recall: 0.9918 - val_loss: 0.0272 - val_accuracy: 0.9935 - val_precision: 0.9892 - val_recall: 0.9978
# Epoch 13/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0304 - accuracy: 0.9910 - precision: 0.9934 - recall: 0.9886 - val_loss: 0.0530 - val_accuracy: 0.9891 - val_precision: 1.0000 - val_recall: 0.9783
# Epoch 14/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0211 - accuracy: 0.9927 - precision: 0.9935 - recall: 0.9918 - val_loss: 0.0376 - val_accuracy: 0.9924 - val_precision: 0.9978 - val_recall: 0.9870
# Epoch 15/100
# 115/115 [==============================] - 16s 140ms/step - loss: 0.0228 - accuracy: 0.9924 - precision: 0.9935 - recall: 0.9913 - val_loss: 0.0133 - val_accuracy: 0.9957 - val_precision: 0.9957 - val_recall: 0.9957
# Epoch 16/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0283 - accuracy: 0.9908 - precision: 0.9924 - recall: 0.9891 - val_loss: 0.0756 - val_accuracy: 0.9880 - val_precision: 1.0000 - val_recall: 0.9761
# Epoch 17/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0185 - accuracy: 0.9946 - precision: 0.9962 - recall: 0.9929 - val_loss: 0.0150 - val_accuracy: 0.9946 - val_precision: 0.9914 - val_recall: 0.9978
# Epoch 18/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0190 - accuracy: 0.9946 - precision: 0.9962 - recall: 0.9929 - val_loss: 0.0165 - val_accuracy: 0.9957 - val_precision: 0.9914 - val_recall: 1.0000
# Epoch 19/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0186 - accuracy: 0.9954 - precision: 0.9967 - recall: 0.9940 - val_loss: 0.1029 - val_accuracy: 0.9685 - val_precision: 0.9407 - val_recall: 1.0000
# Epoch 20/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0192 - accuracy: 0.9929 - precision: 0.9945 - recall: 0.9913 - val_loss: 0.0251 - val_accuracy: 0.9935 - val_precision: 0.9871 - val_recall: 1.0000
# Epoch 21/100
# 115/115 [==============================] - 24s 210ms/step - loss: 0.0254 - accuracy: 0.9910 - precision: 0.9924 - recall: 0.9897 - val_loss: 0.0110 - val_accuracy: 0.9967 - val_precision: 0.9957 - val_recall: 0.9978
# Epoch 22/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0167 - accuracy: 0.9943 - precision: 0.9962 - recall: 0.9924 - val_loss: 0.0333 - val_accuracy: 0.9935 - val_precision: 0.9871 - val_recall: 1.0000
# Epoch 23/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0167 - accuracy: 0.9948 - precision: 0.9956 - recall: 0.9940 - val_loss: 0.0181 - val_accuracy: 0.9946 - val_precision: 0.9892 - val_recall: 1.0000
# Epoch 24/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0169 - accuracy: 0.9957 - precision: 0.9967 - recall: 0.9946 - val_loss: 0.0104 - val_accuracy: 0.9957 - val_precision: 0.9957 - val_recall: 0.9957
# Epoch 25/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0256 - accuracy: 0.9929 - precision: 0.9967 - recall: 0.9891 - val_loss: 0.0091 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 26/100
# 115/115 [==============================] - 22s 192ms/step - loss: 0.0102 - accuracy: 0.9976 - precision: 0.9995 - recall: 0.9957 - val_loss: 0.0066 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 27/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0219 - accuracy: 0.9935 - precision: 0.9940 - recall: 0.9929 - val_loss: 0.0515 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch
-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 99/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0091 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0045 - val_accuracy: 0.9989 - val_precision: 0.9978 - val_recall: 1.0000
# Epoch 100/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0020 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9989 - val_precision: 0.9978 - val_recall: 1.0000
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0010 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# model_Fold = 2 accuracy: 1.0
# model_Fold = 2 precision: 1.0
# model_Fold = 2 recall: 1.0
# model_Fold = 2 f1_score: 1.0
# X_train:  (3680, 178, 1)
# X_val:  (920, 178, 1)
# y_train:  (3680,)
# y_val:  (920,)
#
#
# ---- fold = 3 ------
#
# Epoch 1/100
# 115/115 [==============================] - 31s 157ms/step - loss: 0.1262 - accuracy: 0.9571 - precision: 0.9611 - recall: 0.9527 - val_loss: 0.7429 - val_accuracy: 0.8957 - val_precision: 0.8309 - val_recall: 0.9935
# Epoch 2/100
# 115/115 [==============================] - 14s 119ms/step - loss: 0.0855 - accuracy: 0.9709 - precision: 0.9691 - recall: 0.9728 - val_loss: 0.0933 - val_accuracy: 0.9826 - val_precision: 0.9764 - val_recall: 0.9891
# Epoch 3/100
# 115/115 [==============================] - 15s 128ms/step - loss: 0.0651 - accuracy: 0.9777 - precision: 0.9767 - recall: 0.9788 - val_loss: 0.0407 - val_accuracy: 0.9924 - val_precision: 0.9935 - val_recall: 0.9913
# Epoch 4/100
# 115/115 [==============================] - 15s 134ms/step - loss: 0.0530 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - val_loss: 0.0508 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 5/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0533 - accuracy: 0.9821 - precision: 0.9847 - recall: 0.9793 - val_loss: 0.0466 - val_accuracy: 0.9913 - val_precision: 1.0000 - val_recall: 0.9826
# Epoch 6/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0322 - accuracy: 0.9880 - precision: 0.9891 - recall: 0.9870 - val_loss: 0.0683 - val_accuracy: 0.9783 - val_precision: 0.9622 - val_recall: 0.9957
# Epoch 7/100
# 115/115 [==============================] - 9s 83ms/step - loss: 0.0340 - accuracy: 0.9878 - precision: 0.9902 - recall: 0.9853 - val_loss: 0.0364 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 8/100
# ...
# Epoch 33/100
# 115/115 [==============================] - 9s 83ms/step - loss: 0.0544 - accuracy: 0.9807 - precision: 0.9825 - recall: 0.9788 - val_loss: 0.0144 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 34/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0378 - accuracy: 0.9880 - precision: 0.9891 - recall: 0.9870 - val_loss: 0.0227 - val_accuracy: 0.9946 - val_precision: 0.9978 - val_recall: 0.9913
# Epoch 35/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0318 - accuracy: 0.9908 - precision: 0.9934 - recall: 0.9880 - val_loss: 0.0075 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 36/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0172 - accuracy: 0.9948 - precision: 0.9951 - recall: 0.9946 - val_loss: 0.0164 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 37/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0256 - accuracy: 0.9929 - precision: 0.9940 - recall: 0.9918 - val_loss: 0.0969 - val_accuracy: 0.9913 - val_precision: 0.9829 - val_recall: 1.0000
# Epoch 38/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0228 - accuracy: 0.9940 - precision: 0.9956 - recall: 0.9924 - val_loss: 0.1946 - val_accuracy: 0.9913 - val_precision: 0.9850 - val_recall: 0.9978
# Epoch 39/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0143 - accuracy: 0.9962 - precision: 0.9978 - recall: 0.9946 - val_loss: 0.0077 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 40/100
# 115/115 [==============================] - 20s 176ms/step - loss: 0.0159 - accuracy: 0.9946 - precision: 0.9962 - recall: 0.9929 - val_loss: 0.0047 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 41/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0147 - accuracy: 0.9957 - precision: 0.9973 - recall: 0.9940 - val_loss: 0.0116 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 42/100
# 115/115 [==============================] - 10s 83ms/step - loss: 0.0113 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0077 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 43/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0117 - accuracy: 0.9965 - precision: 0.9973 - recall: 0.9957 - val_loss: 0.0363 - val_accuracy: 0.9978 - val_precision: 0.9957 - val_recall: 1.0000
# Epoch 44/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0144 - accuracy: 0.9951 - precision: 0.9967 - recall: 0.9935 - val_loss: 0.0609 - val_accuracy: 0.9870 - val_precision: 0.9766 - val_recall: 0.9978
# Epoch 45/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0241 - accuracy: 0.9913 - precision: 0.9918 - recall: 0.9908 - val_loss: 0.0228 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 46/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0111 - accuracy: 0.9965 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.0113 - val_accuracy: 0.9957 - val_precision: 0.9935 - val_recall: 0.9978
# Epoch 47/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0064 - accuracy: 0.9986 - precision: 0.9995 - recall: 0.9978 - val_loss: 0.0172 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 48/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0067 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0475 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 49/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0105 - accuracy: 0.9959 - precision: 0.9967 - recall: 0.9951 - val_loss: 0.0838 - val_accuracy: 0.9837 - val_precision: 1.0000 - val_recall: 0.9674
# Epoch 50/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0195 - accuracy: 0.9951 - precision: 0.9967 - recall: 0.9935 - val_loss: 0.0265 - val_accuracy: 0.9913 - val_precision: 1.0000 - val_recall: 0.9826
# Epoch 51/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0161 - accuracy: 0.9943 - precision: 0.9962 - recall: 0.9924 - val_loss: 0.1609 - val_accuracy: 0.9815 - val_precision: 0.9644 - val_recall: 1.0000
# Epoch 52/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0061 - accuracy: 0.9981 - precision: 0.9989 - recall: 0.9973 - val_loss: 0.1746 - val_accuracy: 0.9478 - val_precision: 0.9071 - val_recall: 0.9978
# Epoch 53/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0118 - accuracy: 0.9965 - precision: 0.9973 - recall: 0.9957 - val_loss: 0.1100 - val_accuracy: 0.9826 - val_precision: 0.9684 - val_recall: 0.9978
# Epoch 54/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0143 - accuracy: 0.9962 - precision: 0.9967 - recall: 0.9957 - val_loss: 0.0122 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 55/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0138 - accuracy: 0.9962 - precision: 0.9957 - recall: 0.9967 - val_loss: 0.0272 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 56/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0087 - accuracy: 0.9970 - precision: 0.9973 - recall: 0.9967 - val_loss: 0.1012 - val_accuracy: 0.9728 - val_precision: 0.9485 - val_recall: 1.0000
# Epoch 57/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0051 - accuracy: 0.9970 - precision: 0.9962 - recall: 0.9978 - val_loss: 0.0226 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 58/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0050 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0317 - val_accuracy: 0.9913 - val_precision: 0.9850 - val_recall: 0.9978
# Epoch 59/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0124 - accuracy: 0.9954 - precision: 0.9946 - recall: 0.9962 - val_loss: 0.0083 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 60/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0080 - accuracy: 0.9976 - precision: 0.9984 - recall: 0.9967 - val_loss: 0.0519 - val_accuracy: 0.9946 - val_precision: 0.9935 - val_recall: 0.9957
# Epoch 61/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0045 - accuracy: 0.9981 - precision: 0.9989 - recall: 0.9973 - val_loss: 0.0060 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 62/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0076 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9978 - val_loss: 0.0601 - val_accuracy: 0.9913 - val_precision: 0.9850 - val_recall: 0.9978
# Epoch 63/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0019 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9989 - val_loss: 0.0229 - val_accuracy: 0.9935 - val_precision: 0.9892 - val_recall: 0.9978
# Epoch 64/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0086 - accuracy: 0.9973 - precision: 0.9978 - recall: 0.9967 - val_loss: 0.0093 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 65/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0183 - accuracy: 0.9940 - precision: 0.9946 - recall: 0.9935 - val_loss: 0.0169 - val_accuracy: 0.9967 - val_precision: 0.9935 - val_recall: 1.0000
# Epoch 66/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0043 - accuracy: 0.9986 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.4158 - val_accuracy: 0.9641 - val_precision: 1.0000 - val_recall: 0.9283
# Epoch 67/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0231 - accuracy: 0.9946 - precision: 0.9967 - recall: 0.9924 - val_loss: 0.0202 - val_accuracy: 0.9913 - val_precision: 1.0000 - val_recall: 0.9826
# Epoch 68/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0102 - accuracy: 0.9957 - precision: 0.9957 - recall: 0.9957 - val_loss: 0.0147 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 69/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0070 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.0081 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 70/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0014 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0083 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 71/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0074 - accuracy: 0.9976 - precision: 0.9978 - recall: 0.9973 - val_loss: 0.1320 - val_accuracy: 0.9739 - val_precision: 0.9504 - val_recall: 1.0000
# Epoch 72/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0030 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0364 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 73/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0072 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0660 - val_accuracy: 0.9880 - val_precision: 1.0000 - val_recall: 0.9761
# Epoch 74/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0026 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0183 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 75/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0016 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.3131 - val_accuracy: 0.8837 - val_precision: 0.8113 - val_recall: 1.0000
# Epoch 76/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0104 - accuracy: 0.9976 - precision: 0.9978 - recall: 0.9973 - val_loss: 0.0673 - val_accuracy: 0.9837 - val_precision: 1.0000 - val_recall: 0.9674
# Epoch 77/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0084 - accuracy: 0.9973 - precision: 0.9978 - recall: 0.9967 - val_loss: 0.0945 - val_accuracy: 0.9891 - val_precision: 0.9787 - val_recall: 1.0000
# Epoch 78/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0041 - accuracy: 0.9986 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.1897 - val_accuracy: 0.9239 - val_precision: 0.8679 - val_recall: 1.0000
# Epoch 79/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0016 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0615 - val_accuracy: 0.9891 - val_precision: 1.0000 - val_recall: 0.9783
# Epoch 80/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0038 - accuracy: 0.9989 - precision: 0.9995 - recall: 0.9984 - val_loss: 0.0918 - val_accuracy: 0.9793 - val_precision: 1.0000 - val_recall: 0.9587
# Epoch 81/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0065 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0357 - val_accuracy: 0.9913 - val_precision: 1.0000 - val_recall: 0.9826
# Epoch 82/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0051 - accuracy: 0.9981 - precision: 0.9995 - recall: 0.9967 - val_loss: 0.0052 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 83/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0030 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0066 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 84/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0047 - accuracy: 0.9986 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0038 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 85/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0080 - accuracy: 0.9967 - precision: 0.9973 - recall: 0.9962 - val_loss: 0.0083 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 86/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0101 - accuracy: 0.9970 - precision: 0.9973 - recall: 0.9967 - val_loss: 0.0326 - val_accuracy: 0.9880 - val_precision: 0.9787 - val_recall: 0.9978
# Epoch 87/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0077 - accuracy: 0.9970 - precision: 0.9967 - recall: 0.9973 - val_loss: 0.0295 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 88/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0058 - accuracy: 0.9984 - precision: 0.9995 - recall: 0.9973 - val_loss: 0.0100 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 89/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0027 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0114 - val_accuracy: 0.9967 - val_precision: 0.9957 - val_recall: 0.9978
# Epoch 90/100
# 115/115 [==============================] - 9s 82ms/step - loss: 3.8115e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 91/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0041 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0369 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 92/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0037 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9989 - val_loss: 0.0082 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 93/100
# 115/115 [==============================] - 9s 82ms/step - loss: 2.4838e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 94/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0090 - accuracy: 0.9973 - precision: 0.9967 - recall: 0.9978 - val_loss: 0.0089 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 95/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0115 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.0048 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 96/100
# 115/115 [==============================] - 9s 82ms/step - loss: 4.0461e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 97/100
# 115/115 [==============================] - 9s 82ms/step - loss: 6.4651e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0076 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 98/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0119 - accuracy: 0.9957 - precision: 0.9951 - recall: 0.9962 - val_loss: 0.0325 - val_accuracy: 0.9902 - val_precision: 0.9829 - val_recall: 0.9978
# Epoch 99/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0063 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0091 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 100/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0040 - accuracy: 0.9986 - precision: 0.9978 - recall: 0.9995 - val_loss: 0.0581 - val_accuracy: 0.9870 - val_precision: 1.0000 - val_recall: 0.9739
# 29/29 [==============================] - 2s 24ms/step - loss: 0.0047 - accuracy: 0.9989 - precision: 1.0000 - recall: 0.9978
# model_Fold = 5 accuracy: 0.998913049697876
# model_Fold = 5 precision: 1.0
# model_Fold = 5 recall: 0.997826099395752
# model_Fold = 5 f1_score: 0.9989118669513299
# Mean Accuracy: 0.9997826099395752
# Mean Precision: 1.0
# Mean Recall: 0.9995652198791504
# Mean F1_Score: 0.999782562670861
