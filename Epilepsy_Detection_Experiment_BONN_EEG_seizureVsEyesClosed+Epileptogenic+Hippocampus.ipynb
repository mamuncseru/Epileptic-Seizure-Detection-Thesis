# %% [markdown]
# ## Investigating the Impact of Residual Connection to Convolutional Layer on EEG Classification Performance

# %% [markdown]
# ### Experiment Summary:
#
# **This experiment aims to explore the influence of residual connection with convolutional layers on the performance of EEG classification models. We investigate the relationship between the number of convolutional layers and the resulting accuracy.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %mkdir /content/drive/MyDrive/ED_Experiments
# %mkdir /content/drive/MyDrive/ED_Experiments/ED_CNN_E13

# %%
# %mkdir /content/drive/MyDrive/ED_Experiments/EyesClosed+Epileptogenic+Hippocampus
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/ED_Experiments/EyesClosed+Epileptogenic+Hippocampus’: File exists

# %%
# %cd /content/drive/MyDrive/ED_Experiments/EyesClosed+Epileptogenic+Hippocampus
# %ls
# Out:
# /content/drive/MyDrive/ED_Experiments/EyesClosed+Epileptogenic+Hippocampus
# model_fold_1.h5                    model_fold_3.log
# model_fold_1.log                   model_fold_3_loss_accuracy.png
# model_fold_1_loss_accuracy.png     model_fold_3_precision_recall.png
# model_fold_1_precision_recall.png  model_fold_4.h5
# model_fold_2.h5                    model_fold_4.log
# model_fold_2.log                   model_fold_4_loss_accuracy.png
# model_fold_2_loss_accuracy.png     model_fold_4_precision_recall.png
# model_fold_2_precision_recall.png  model_fold_5.h5
# model_fold_3.h5                    model_fold_5.log

# %% [markdown]
# ## Import libraries

# %%
import sys
import os
import logging


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, StratifiedKFold

from tqdm import tqdm

import keras
from keras.layers import Dense, Convolution1D, MaxPool1D, Flatten, Dropout
from keras.layers import Input, LSTM
from keras.layers import BatchNormalization
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import metrics

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
## seed
np.random.seed(2023)

# %% [markdown]
# ### Reading CSV data

# %%
raw_data = pd.read_csv('https://raw.githubusercontent.com/mamuncseru/analysis_on_epileptic_seizure_bonn_dataset/main/Epileptic%20Seizure%20Recognition.csv')
raw_data.shape
# Out:
# (11500, 180)

# %%
raw_data
# Out:
#           Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  \
# 0      X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17
# 1      X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164
# 2         X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57
# 3       X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82
# 4       X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 11495  X22.V1.114  -22  -22  -23  -26  -36  -42  -45  -42  -45  ...    15
# 11496  X19.V1.354  -47  -11   28   77  141  211  246  240  193  ...   -65
# 11497    X8.V1.28   14    6  -13  -16   10   26   27   -9    4  ...   -65
# 11498  X10.V1.932  -40  -25   -9  -12   -2   12    7   19   22  ...   121
# 11499  X16.V1.210   29   41   57   72   74   62   54   43   31  ...   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# 0       -15   -31   -77  -103  -127  -116   -83   -51  4
# 1       150   146   152   157   156   154   143   129  1
# 2        64    48    19   -12   -30   -35   -35   -36  5
# 3       -81   -80   -77   -85   -77   -72   -69   -65  5
# 4         2   -12   -32   -41   -65   -83   -89   -73  5
# ...     ...   ...   ...   ...   ...   ...   ...   ... ..
# 11495    16    12     5    -1   -18   -37   -47   -48  2
# 11496   -33    -7    14    27    48    77   117   170  1
# 11497   -48   -61   -62   -67   -30    -2    -1    -8  5
# 11498   135   148   143   116    86    68    59    55  3
# 11499   -25    -4     2     5     4    -2     2    20  4
#
# [11500 rows x 180 columns]

# %%
raw_data.values.shape
# Out:
# (11500, 180)

# %%
data = raw_data.values # converted to an numpy array
data = data[:, 1:] # discarding the Unnamed Column
data.shape
# Out:
# (11500, 179)

# %%
# let's see how it looks like
data
# Out:
# array([[135, 190, 229, ..., -83, -51, 4],
#        [386, 382, 356, ..., 143, 129, 1],
#        [-32, -39, -47, ..., -35, -36, 5],
#        ...,
#        [14, 6, -13, ..., -1, -8, 5],
#        [-40, -25, -9, ..., 59, 55, 3],
#        [29, 41, 57, ..., 2, 20, 4]], dtype=object)

# %%
# let's see the type
type(data)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Classifying data categories as it mentioned in the paper

# %%
df_1 = data[data[:, -1] == 1].astype(int) # seizure
df_2 = data[data[:, -1] == 2].astype(int)
df_3 = data[data[:, -1] == 3].astype(int)
df_4 = data[data[:, -1] == 4].astype(int)
df_5 = data[data[:, -1] == 5].astype(int)

# let's print the shape of each category
print(df_1.shape)
print(df_2.shape)
print(df_3.shape)
print(df_4.shape)
print(df_5.shape)
# Out:
# (2300, 179)
# (2300, 179)
# (2300, 179)
# (2300, 179)
# (2300, 179)

# %% [markdown]
# ## Let's plot some random data points from every category

# %%
def visualize_eeg(number_of_datapoints):
    for i in (np.random.randint(0, 2300, number_of_datapoints)):
        plt.plot(df_1[i, :], 'r-', label='df_1')
        plt.plot(df_2[i, :], 'm-', label='df_2')
        plt.plot(df_3[i, :], 'b-', label='df_3')
        plt.plot(df_4[i, :], 'k-', label='df_4')
        plt.legend()
        plt.title(f'Eyes closed + Epileptogenic + Hippocampus vs Seizure data visualizing {i} th data point')
        plt.xlabel('time')
        plt.ylabel('aplitude(uV)')
        plt.show()

# %% [markdown]
# ### Visualizing all categories in single figure

# %%
### all categories
visualize_eeg(5)

# %% [markdown]
# ## Converting data into integer and making the data into seizure and non-seizure cateogry

# %%
data = np.concatenate((df_1, df_2, df_3, df_4))

# %% [markdown]
# ## Plot functions

# %% [markdown]
# ### function to plot loss curve of the
# - (training and validation loss) and
# - (training and validation accuracy)

# %%
def plot_loss_accuracy(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(14, 6))

    ax[0].plot(history.history['loss'], 'b-')
    ax[0].plot(history.history['val_loss'], 'r-')
    ax[0].legend(['train_loss', 'val_loss'])
    ax[0].set_title('Loss curve')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss %')

    ax[1].plot(history.history['accuracy'], 'b-')
    ax[1].plot(history.history['val_accuracy'], 'r-')
    ax[1].legend(['train_accuracy', 'val_accuracy'])
    ax[1].set_title('Accuracy curve')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('accuracy %')

    plt.suptitle(title)
    plt.savefig(title + '_loss_accuracy.png')

    plt.show()

# %%
def plot_precision_recall(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(14, 6))

    ax[0].plot(history.history['precision'], 'b-')
    ax[0].plot(history.history['val_precision'], 'r-')
    ax[0].legend(['train_precision', 'val_precision'])
    ax[0].set_title('precision curve')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Precision %')

    ax[1].plot(history.history['recall'], 'b-')
    ax[1].plot(history.history['val_recall'], 'r-')
    ax[1].legend(['train_recall', 'val_recall'])
    ax[1].set_title('recall curve')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Recall %')

    plt.suptitle(title)
    plt.savefig(title + '_precision_recall.png')

    plt.show()

# %%
# Initialize StratifiedKFold with 5 folds
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=2023)

# %%
def input_output_data(data, random_state=2023):
    data[:, -1] = np.where(data[:, -1] != 1, 0, data[:, -1])

    X = data[:, :-1]
    y = data[:, -1]

    return X, y

X, y = input_output_data(data)

# %%
X.shape
# Out:
# (9200, 178)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
def process_input(X, y, train_index, val_index):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    X_train = np.expand_dims(X_train, axis=2)
    X_val = np.expand_dims(X_val, axis=2)

    input_shape = (X_train.shape[1], 1)

    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')


    return X_train, X_val, y_train, y_val, input_shape

# %% [markdown]
# ## Logger setup

# %%
import absl.logging
import sys
import logging
absl.logging.set_verbosity(absl.logging.ERROR)
absl.logging.set_verbosity(absl.logging.INFO)

# %%
def init_logger(log_file, log_level=logging.INFO, stdout=True):
    logger = logging.getLogger()
    logger.setLevel(log_level)

    formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')

    file_handler = logging.FileHandler(log_file, mode='w')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    if stdout:
        console_handler = logging.StreamHandler(sys.stdout)
        console_handler.setFormatter(formatter)
        logger.addHandler(console_handler)

    return logger

# %% [markdown]
# ## Let's experiment with the Residual Connection

# %%
def residual_block(x, filters, kernel_size, padding='same', activation='relu'):
    shortcut = x
    x = layers.Conv1D(filters=filters, kernel_size=kernel_size, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(activation)(x)
    x = layers.Conv1D(filters=filters, kernel_size=kernel_size, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([shortcut, x])
    x = layers.Activation(activation)(x)
    return x

def create_residual_eeg_model(input_shape):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv1D(filters=128, kernel_size=5, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=128, kernel_size=5)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=256, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=256, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=512, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=512, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=1024, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=1024, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=2048, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=2048, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.GlobalAveragePooling1D()(x)  # Replace Flatten layer with GlobalAveragePooling1D
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Perform cross-validation
fold_accuracy = []
fold_precision = []
fold_recall = []
fold_f1score = []
fold = 1

for train_index, val_index in skf.split(X, y):
    X_train, X_val, y_train, y_val, input_shape = process_input(X, y, train_index, val_index)
    print('X_train: ', X_train.shape)
    print('X_val: ', X_val.shape)
    print('y_train: ', y_train.shape)
    print('y_val: ', y_val.shape)


    # model = eegClassifier(input_shape)
    model = create_residual_eeg_model(input_shape)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',
                                                                         tf.keras.metrics.Precision(name='precision'),
                                                                         tf.keras.metrics.Recall(name='recall')])
    log_file = f"model_fold_{fold}.log"
    model_name = f"model_fold_{fold}.h5"

    # Clear existing log handlers and close log files
    root_logger = logging.getLogger()
    for handler in root_logger.handlers:
        handler.close()
    root_logger.handlers.clear()

    # Create a separate log file for each model
    logger = init_logger(log_file, stdout=False)


    logger.info(f"\n\n---- fold = {fold} -------\n")
    print(f"\n\n---- fold = {fold} ------\n")

    # Define the checkpoint callback to save the best model
    checkpoint = ModelCheckpoint(model_name, monitor='val_accuracy', save_best_only=True, mode='max', save_format="h5")

    # Train the model and capture the history
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,
                        callbacks=[checkpoint])

    # Log loss and accuracy
    for i, (loss, accuracy, precision, recall) in enumerate(zip(history.history['loss'],
                                                                history.history['accuracy'],
                                                                history.history['precision'],
                                                                history.history['recall'])):
        logger.info(f"Epoch {i+1} - Loss: {loss} - Accuracy: {accuracy} - Precision: {precision} - Recall: {recall}")

    for i, (val_loss, val_accuracy, val_precision, val_recall) in enumerate(zip(history.history['val_loss'],
                                                                                history.history['val_accuracy'],
                                                                                history.history['val_precision'],
                                                                                history.history['val_recall'])):
        logger.info(f"Epoch {i+1} - Validation Loss: {val_loss} - Validation Accuracy: {val_accuracy}")


    # Evaluate the model
    best_model_path = model_name
    best_model = tf.keras.models.load_model(best_model_path)
    loss_scale_optimizer, accuracy, precision, recall = best_model.evaluate(X_val, y_val)
    fold_accuracy.append(accuracy)
    fold_precision.append(precision)
    fold_recall.append(recall)

    # Log fold accuracy
    logger.info(f"model_Fold = {fold} accuracy: {accuracy}")
    logger.info(f"model_Fold = {fold} precision: {precision}")
    logger.info(f"model_Fold = {fold} recall: {recall}")


    print(f"model_Fold = {fold} accuracy: {accuracy}")
    print(f"model_Fold = {fold} precision: {precision}")
    print(f"model_Fold = {fold} recall: {recall}")
    print(f"model_Fold = {fold} f1_score: {2*(precision*recall) / (precision + recall)}")

    plot_loss_accuracy(history, f"model_fold_{fold}")
    plot_precision_recall(history, f"model_fold_{fold}")
    # plot_accuracy(history)

    fold += 1

# Calculate the average accuracy across all folds
mean_accuracy = np.mean(fold_accuracy)
mean_precision = np.mean(fold_precision)
mean_recall = np.mean(fold_recall)
mean_f1_score = 2 * (mean_precision * mean_recall) / (mean_precision + mean_recall)

print("Mean Accuracy:", mean_accuracy)
print("Mean Precision:", mean_precision)
print("Mean Recall:", mean_recall)
print("Mean F1_Score:", mean_f1_score)
# Out:
# X_train:  (7360, 178, 1)
# X_val:  (1840, 178, 1)
# y_train:  (7360,)
# y_val:  (1840,)
#
#
# ---- fold = 1 ------
#
# Epoch 1/100
# 230/230 [==============================] - 47s 89ms/step - loss: 0.1659 - accuracy: 0.9423 - precision: 0.8955 - recall: 0.8707 - val_loss: 0.6900 - val_accuracy: 0.7196 - val_precision: 0.4712 - val_recall: 0.9957
# Epoch 2/100
# 230/230 [==============================] - 24s 103ms/step - loss: 0.1101 - accuracy: 0.9614 - precision: 0.9242 - recall: 0.9212 - val_loss: 0.2267 - val_accuracy: 0.9033 - val_precision: 0.7245 - val_recall: 0.9891
# Epoch 3/100
# 230/230 [==============================] - 25s 109ms/step - loss: 0.1114 - accuracy: 0.9626 - precision: 0.9260 - recall: 0.9245 - val_loss: 0.1532 - val_accuracy: 0.9370 - val_precision: 0.8028 - val_recall: 0.9913
# Epoch 4/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0855 - accuracy: 0.9717 - precision: 0.9454 - recall: 0.9413 - val_loss: 0.0936 - val_accuracy: 0.9663 - val_precision: 0.9112 - val_recall: 0.9587
# Epoch 5/100
# 230/230 [==============================] - 20s 88ms/step - loss: 0.0961 - accuracy: 0.9655 - precision: 0.9357 - recall: 0.9255 - val_loss: 0.0808 - val_accuracy: 0.9696 - val_precision: 0.9676 - val_recall: 0.9087
# Epoch 6/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0776 - accuracy: 0.9757 - precision: 0.9531 - recall: 0.9495 - val_loss: 0.0801 - val_accuracy: 0.9674 - val_precision: 0.9950 - val_recall: 0.8739
# Epoch 7/100
# 230/230 [==============================] - 29s 126ms/step - loss: 0.0792 - accuracy: 0.9719 - precision: 0.9479 - recall: 0.9391 - val_loss: 0.0549 - val_accuracy: 0.9810 - val_precision: 0.9885 - val_recall: 0.9348
# Epoch 8/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0624 - accuracy: 0.9789 - precision: 0.9627 - recall: 0.9527 - val_loss: 0.0731 - val_accuracy: 0.9739 - val_precision: 0.9928 - val_recall: 0.9022
# Epoch 9/100
# 230/230 [==============================] - 25s 111ms/step - loss: 0.0708 - accuracy: 0.9766 - precision: 0.9572 - recall: 0.9489 - val_loss: 0.0410 - val_accuracy: 0.9859 - val_precision: 0.9844 - val_recall: 0.9587
# Epoch 10/100
# 230/230 [==============================] - 23s 101ms/step - loss: 0.0544 - accuracy: 0.9791 - precision: 0.9602 - recall: 0.9560 - val_loss: 0.0365 - val_accuracy: 0.9870 - val_precision: 0.9844 - val_recall: 0.9630
# Epoch 11/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0519 - accuracy: 0.9822 - precision: 0.9687 - recall: 0.9598 - val_loss: 0.0369 - val_accuracy: 0.9870 - val_precision: 0.9619 - val_recall: 0.9870
# Epoch 12/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0447 - accuracy: 0.9836 - precision: 0.9704 - recall: 0.9636 - val_loss: 0.0352 - val_accuracy: 0.9853 - val_precision: 0.9954 - val_recall: 0.9457
# Epoch 13/100
# 230/230 [==============================] - 29s 124ms/step - loss: 0.0424 - accuracy: 0.9852 - precision: 0.9758 - recall: 0.9647 - val_loss: 0.0296 - val_accuracy: 0.9913 - val_precision: 0.9826 - val_recall: 0.9826
# Epoch 14/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0345 - accuracy: 0.9879 - precision: 0.9782 - recall: 0.9734 - val_loss: 0.0759 - val_accuracy: 0.9739 - val_precision: 0.9087 - val_recall: 0.9957
# Epoch 15/100
# 230/230 [==============================] - 28s 123ms/step - loss: 0.0351 - accuracy: 0.9894 - precision: 0.9788 - recall: 0.9788 - val_loss: 0.0207 - val_accuracy: 0.9929 - val_precision: 0.9934 - val_recall: 0.9783
# Epoch 16/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0274 - accuracy: 0.9902 - precision: 0.9799 - recall: 0.9810 - val_loss: 0.0347 - val_accuracy: 0.9880 - val_precision: 0.9620 - val_recall: 0.9913
# Epoch 17/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0400 - accuracy: 0.9857 - precision: 0.9753 - recall: 0.9674 - val_loss: 0.0285 - val_accuracy: 0.9918 - val_precision: 0.9869 - val_recall: 0.9804
# Epoch 18/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0294 - accuracy: 0.9890 - precision: 0.9777 - recall: 0.9783 - val_loss: 0.0325 - val_accuracy: 0.9913 - val_precision: 0.9933 - val_recall: 0.9717
# Epoch 19/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0245 - accuracy: 0.9917 - precision: 0.9811 - recall: 0.9859 - val_loss: 0.0278 - val_accuracy: 0.9918 - val_precision: 0.9764 - val_recall: 0.9913
# Epoch 20/100
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0318 - accuracy: 0.9901 - precision: 0.9794 - recall: 0.9810 - val_loss: 0.0511 - val_accuracy: 0.9810 - val_precision: 0.9930 - val_recall: 0.9304
# Epoch 21/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0267 - accuracy: 0.9913 - precision: 0.9821 - recall: 0.9832 - val_loss: 0.0250 - val_accuracy: 0.9929 - val_precision: 0.9765 - val_recall: 0.9957
# Epoch 22/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0251 - accuracy: 0.9908 - precision: 0.9831 - recall: 0.9799 - val_loss: 0.0283 - val_accuracy: 0.9902 - val_precision: 0.9804 - val_recall: 0.9804
# Epoch 23/100
# 230/230 [==============================] - 29s 124ms/step - loss: 0.0162 - accuracy: 0.9946 - precision: 0.9907 - recall: 0.9875 - val_loss: 0.0177 - val_accuracy: 0.9951 - val_precision: 0.9913 - val_recall: 0.9891
# Epoch 24/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0154 - accuracy: 0.9943 - precision: 0.9881 - recall: 0.9891 - val_loss: 0.0524 - val_accuracy: 0.9908 - val_precision: 0.9933 - val_recall: 0.9696
# Epoch 25/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0253 - accuracy: 0.9909 - precision: 0.9805 - recall: 0.9832 - val_loss: 0.0296 - val_accuracy: 0.9908 - val_precision: 0.9743 - val_recall: 0.9891
# Epoch 26/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0205 - accuracy: 0.9933 - precision: 0.9854 - recall: 0.9880 - val_loss: 0.0275 - val_accuracy: 0.9918 - val_precision: 0.9764 - val_recall: 0.9913
# Epoch 27/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0118 - accuracy: 0.9962 - precision: 0.9919 - recall: 0.9929 - val_loss: 0.0331 - val_accuracy: 0.9891 - val_precision: 0.9701 - val_recall: 0.9870
# Epoch 28/100
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0123 - accuracy: 0.9958 - precision: 0.9902 - recall: 0.9929 - val_loss: 0.0307 - val_accuracy: 0.9880 - val_precision: 0.9932 - val_recall: 0.9587
# Epoch 29/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0168 - accuracy: 0.9936 - precision: 0.9880 - recall: 0.9864 - val_loss: 0.0301 - val_accuracy: 0.9924 - val_precision: 0.9869 - val_recall: 0.9826
# Epoch 30/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0161 - accuracy: 0.9947 - precision: 0.9897 - recall: 0.9891 - val_loss: 0.0231 - val_accuracy: 0.9946 - val_precision: 0.9913 - val_recall: 0.9870
# Epoch 31/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0094 - accuracy: 0.9970 - precision: 0.9951 - recall: 0.9929 - val_loss: 0.0440 - val_accuracy: 0.9853 - val_precision: 0.9676 - val_recall: 0.9739
# Epoch 32/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0174 - accuracy: 0.9944 - precision: 0.9891 - recall: 0.9886 - val_loss: 0.0252 - val_accuracy: 0.9924 - val_precision: 0.9869 - val_recall: 0.9826
# Epoch 33/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0141 - accuracy: 0.9947 - precision: 0.9875 - recall: 0.9913 - val_loss: 0.0479 - val_accuracy: 0.9908 - val_precision: 0.9978 - val_recall: 0.9652
# Epoch 34/100
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0187 - accuracy: 0.9940 - precision: 0.9880 - recall: 0.9880 - val_loss: 0.0231 - val_accuracy: 0.9913 - val_precision: 0.9868 - val_recall: 0.9783
# Epoch 35/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0078 - accuracy: 0.9981 - precision: 0.9973 - recall: 0.9951 - val_loss: 0.0197 - val_accuracy: 0.9929 - val_precision: 0.9912 - val_recall: 0.9804
# Epoch 36/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0112 - accuracy: 0.9961 - precision: 0.9908 - recall: 0.9935 - val_loss: 0.0316 - val_accuracy: 0.9924 - val_precision: 0.9934 - val_recall: 0.9761
# Epoch 37/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0113 - accuracy: 0.9959 - precision: 0.9929 - recall: 0.9908 - val_loss: 0.0329 - val_accuracy: 0.9913 - val_precision: 0.9978 - val_recall: 0.9674
# Epoch 38/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0156 - accuracy: 0.9950 - precision: 0.9881 - recall: 0.9918 - val_loss: 0.0701 - val_accuracy: 0.9804 - val_precision: 0.9930 - val_recall: 0.9283
# Epoch 39/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0247 - accuracy: 0.9948 - precision: 0.9876 - recall: 0.9918 - val_loss: 0.0224 - val_accuracy: 0.9935 - val_precision: 0.9934 - val_recall: 0.9804
# Epoch 40/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0165 - accuracy: 0.9939 - precision: 0.9886 - recall: 0.9870 - val_loss: 0.0191 - val_accuracy: 0.9935 - val_precision: 0.9828 - val_recall: 0.9913
# Epoch 41/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0069 - accuracy: 0.9977 - precision: 0.9956 - recall: 0.9951 - val_loss: 0.0364 - val_accuracy: 0.9918 - val_precision: 0.9955 - val_recall: 0.9717
# Epoch 42/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0044 - accuracy: 0.9978 - precision: 0.9962 - recall: 0.9951 - val_loss: 0.0361 - val_accuracy: 0.9935 - val_precision: 0.9956 - val_recall: 0.9783
# Epoch 43/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0101 - accuracy: 0.9970 - precision: 0.9935 - recall: 0.9946 - val_loss: 0.0440 - val_accuracy: 0.9848 - val_precision: 0.9596 - val_recall: 0.9804
# Epoch 44/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0092 - accuracy: 0.9969 - precision: 0.9935 - recall: 0.9940 - val_loss: 0.0297 - val_accuracy: 0.9897 - val_precision: 0.9977 - val_recall: 0.9609
# Epoch 45/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0065 - accuracy: 0.9973 - precision: 0.9956 - recall: 0.9935 - val_loss: 0.0544 - val_accuracy: 0.9837 - val_precision: 1.0000 - val_recall: 0.9348
# Epoch 46/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0011 - accuracy: 0.9995 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0222 - val_accuracy: 0.9951 - val_precision: 0.9978 - val_recall: 0.9826
# Epoch 47/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0197 - accuracy: 0.9944 - precision: 0.9865 - recall: 0.9913 - val_loss: 0.0324 - val_accuracy: 0.9940 - val_precision: 0.9912 - val_recall: 0.9848
# Epoch 48/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0027 - accuracy: 0.9989 - precision: 0.9973 - recall: 0.9984 - val_loss: 0.0500 - val_accuracy: 0.9913 - val_precision: 0.9912 - val_recall: 0.9739
# Epoch 49/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0134 - accuracy: 0.9959 - precision: 0.9913 - recall: 0.9924 - val_loss: 0.0266 - val_accuracy: 0.9940 - val_precision: 0.9870 - val_recall: 0.9891
# Epoch 50/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0053 - accuracy: 0.9990 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0370 - val_accuracy: 0.9897 - val_precision: 0.9955 - val_recall: 0.9630
# Epoch 51/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0040 - accuracy: 0.9988 - precision: 0.9984 - recall: 0.9967 - val_loss: 0.0236 - val_accuracy: 0.9946 - val_precision: 0.9891 - val_recall: 0.9891
# Epoch 52/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0198 - accuracy: 0.9947 - precision: 0.9881 - recall: 0.9908 - val_loss: 0.0220 - val_accuracy: 0.9940 - val_precision: 0.9912 - val_recall: 0.9848
# Epoch 53/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0060 - accuracy: 0.9976 - precision: 0.9956 - recall: 0.9946 - val_loss: 0.0259 - val_accuracy: 0.9908 - val_precision: 0.9890 - val_recall: 0.9739
# Epoch 54/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0020 - accuracy: 0.9996 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0340 - val_accuracy: 0.9951 - val_precision: 0.9956 - val_recall: 0.9848
# Epoch 55/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0052 - accuracy: 0.9980 - precision: 0.9946 - recall: 0.9973 - val_loss: 0.0257 - val_accuracy: 0.9946 - val_precision: 0.9934 - val_recall: 0.9848
# Epoch 56/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0131 - accuracy: 0.9962 - precision: 0.9908 - recall: 0.9940 - val_loss: 0.0220 - val_accuracy: 0.9935 - val_precision: 0.9828 - val_recall: 0.9913
# Epoch 57/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0122 - accuracy: 0.9970 - precision: 0.9951 - recall: 0.9929 - val_loss: 0.0293 - val_accuracy: 0.9918 - val_precision: 0.9978 - val_recall: 0.9696
# Epoch 58/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0056 - accuracy: 0.9982 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.0174 - val_accuracy: 0.9940 - val_precision: 0.9934 - val_recall: 0.9826
# Epoch 59/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0015 - accuracy: 0.9995 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0203 - val_accuracy: 0.9946 - val_precision: 0.9956 - val_recall: 0.9826
# Epoch 60/100
# 230/230 [==============================] - 18s 78ms/step - loss: 1.0549e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9951 - val_precision: 0.9934 - val_recall: 0.9870
# Epoch 61/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0080 - accuracy: 0.9978 - precision: 0.9951 - recall: 0.9962 - val_loss: 0.0292 - val_accuracy: 0.9924 - val_precision: 0.9869 - val_recall: 0.9826
# Epoch 62/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0060 - accuracy: 0.9980 - precision: 0.9957 - recall: 0.9962 - val_loss: 0.0568 - val_accuracy: 0.9875 - val_precision: 0.9955 - val_recall: 0.9543
# Epoch 63/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0047 - accuracy: 0.9989 - precision: 0.9973 - recall: 0.9984 - val_loss: 0.0159 - val_accuracy: 0.9940 - val_precision: 0.9891 - val_recall: 0.9870
# Epoch 64/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0043 - accuracy: 0.9985 - precision: 0.9962 - recall: 0.9978 - val_loss: 0.0333 - val_accuracy: 0.9929 - val_precision: 0.9934 - val_recall: 0.9783
# Epoch 65/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0045 - accuracy: 0.9984 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.0303 - val_accuracy: 0.9924 - val_precision: 0.9848 - val_recall: 0.9848
# Epoch 66/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0064 - accuracy: 0.9982 - precision: 0.9946 - recall: 0.9984 - val_loss: 0.1117 - val_accuracy: 0.9696 - val_precision: 0.9056 - val_recall: 0.9804
# Epoch 67/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0100 - accuracy: 0.9971 - precision: 0.9946 - recall: 0.9940 - val_loss: 0.0244 - val_accuracy: 0.9940 - val_precision: 0.9934 - val_recall: 0.9826
# Epoch 68/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0039 - accuracy: 0.9989 - precision: 0.9973 - recall: 0.9984 - val_loss: 0.0354 - val_accuracy: 0.9913 - val_precision: 0.9912 - val_recall: 0.9739
# Epoch 69/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0035 - accuracy: 0.9988 - precision: 0.9973 - recall: 0.9978 - val_loss: 0.0304 - val_accuracy: 0.9935 - val_precision: 0.9956 - val_recall: 0.9783
# Epoch 70/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0013 - accuracy: 0.9993 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0302 - val_accuracy: 0.9913 - val_precision: 0.9978 - val_recall: 0.9674
# Epoch 71/100
# 230/230 [==============================] - 18s 78ms/step - loss: 5.8017e-04 - accuracy: 0.9997 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0565 - val_accuracy: 0.9924 - val_precision: 0.9978 - val_recall: 0.9717
# Epoch 72/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0090 - accuracy: 0.9977 - precision: 0.9951 - recall: 0.9957 - val_loss: 0.0222 - val_accuracy: 0.9929 - val_precision: 0.9956 - val_recall: 0.9761
# Epoch 73/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0035 - accuracy: 0.9988 - precision: 0.9967 - recall: 0.9984 - val_loss: 0.0369 - val_accuracy: 0.9908 - val_precision: 0.9847 - val_recall: 0.9783
# Epoch 74/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0107 - accuracy: 0.9970 - precision: 0.9946 - recall: 0.9935 - val_loss: 0.0215 - val_accuracy: 0.9946 - val_precision: 0.9934 - val_recall: 0.9848
# Epoch 75/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0019 - accuracy: 0.9992 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0201 - val_accuracy: 0.9935 - val_precision: 0.9956 - val_recall: 0.9783
# Epoch 76/100
# 230/230 [==============================] - 18s 78ms/step - loss: 3.0712e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9946 - val_precision: 0.9956 - val_recall: 0.9826
# Epoch 77/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0026 - accuracy: 0.9993 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0287 - val_accuracy: 0.9946 - val_precision: 0.9956 - val_recall: 0.9826
# Epoch 78/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0110 - accuracy: 0.9967 - precision: 0.9929 - recall: 0.9940 - val_loss: 0.0336 - val_accuracy: 0.9924 - val_precision: 0.9827 - val_recall: 0.9870
# Epoch 79/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0016 - accuracy: 0.9995 - precision: 0.9984 - recall: 0.9995 - val_loss: 0.0404 - val_accuracy: 0.9913 - val_precision: 0.9933 - val_recall: 0.9717
# Epoch 80/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0026 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9978 - val_loss: 0.0341 - val_accuracy: 0.9918 - val_precision: 0.9869 - val_recall: 0.9804
# Epoch 81/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0034 - accuracy: 0.9993 - precision: 0.9978 - recall: 0.9995 - val_loss: 0.0402 - val_accuracy: 0.9929 - val_precision: 0.9934 - val_recall: 0.9783
# Epoch 82/100
# 230/230 [==============================] - 18s 79ms/step - loss: 5.8834e-04 - accuracy: 0.9997 - precision: 0.9989 - recall: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9929 - val_precision: 0.9956 - val_recall: 0.9761
# Epoch 83/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0041 - accuracy: 0.9988 - precision: 0.9978 - recall: 0.9973 - val_loss: 0.0320 - val_accuracy: 0.9929 - val_precision: 0.9978 - val_recall: 0.9739
# Epoch 84/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0011 - accuracy: 0.9993 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0214 - val_accuracy: 0.9951 - val_precision: 0.9956 - val_recall: 0.9848
# Epoch 85/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0071 - accuracy: 0.9990 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0384 - val_accuracy: 0.9902 - val_precision: 0.9933 - val_recall: 0.9674
# Epoch 86/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0097 - accuracy: 0.9974 - precision: 0.9940 - recall: 0.9957 - val_loss: 0.0255 - val_accuracy: 0.9951 - val_precision: 0.9978 - val_recall: 0.9826
# Epoch 87/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0051 - accuracy: 0.9982 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.0206 - val_accuracy: 0.9951 - val_precision: 0.9913 - val_recall: 0.9891
# Epoch 88/100
# 230/230 [==============================] - 29s 125ms/step - loss: 1.7303e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9957 - val_precision: 0.9956 - val_recall: 0.9870
# Epoch 89/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0059 - accuracy: 0.9985 - precision: 0.9967 - recall: 0.9973 - val_loss: 0.0237 - val_accuracy: 0.9940 - val_precision: 0.9956 - val_recall: 0.9804
# Epoch 90/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0075 - accuracy: 0.9981 - precision: 0.9962 - recall: 0.9962 - val_loss: 0.0217 - val_accuracy: 0.9940 - val_precision: 0.9934 - val_recall: 0.9826
# Epoch 91/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0015 - accuracy: 0.9995 - precision: 0.9984 - recall: 0.9995 - val_loss: 0.0278 - val_accuracy: 0.9918 - val_precision: 0.9978 - val_recall: 0.9696
# Epoch 92/100
# 230/230 [==============================] - 18s 78ms/step - loss: 2.1659e-04 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0252 - val_accuracy: 0.9935 - val_precision: 0.9978 - val_recall: 0.9761
# Epoch 93/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0026 - accuracy: 0.9993 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0366 - val_accuracy: 0.9918 - val_precision: 0.9933 - val_recall: 0.9739
# Epoch 94/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0059 - accuracy: 0.9978 - precision: 0.9957 - recall: 0.9957 - val_loss: 0.0279 - val_accuracy: 0.9918 - val_precision: 0.9978 - val_recall: 0.9696
# Epoch 95/100
# 230/230 [==============================] - 28s 120ms/step - loss: 0.0013 - accuracy: 0.9996 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0157 - val_accuracy: 0.9967 - val_precision: 0.9935 - val_recall: 0.9935
# Epoch 96/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.0293e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9967 - val_precision: 0.9956 - val_recall: 0.9913
# Epoch 97/100
# 230/230 [==============================] - 18s 79ms/step - loss: 2.4902e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9957 - val_precision: 0.9956 - val_recall: 0.9870
# Epoch 98/100
# 230/230 [==============================] - 18s 79ms/step - loss: 1.8422e-04 - accuracy: 0.9999 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9946 - val_precision: 0.9956 - val_recall: 0.9826
# Epoch 99/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0028 - accuracy: 0.9993 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0201 - val_accuracy: 0.9957 - val_precision: 0.9956 - val_recall: 0.9870
# Epoch 100/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0028 - accuracy: 0.9989 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0414 - val_accuracy: 0.9929 - val_precision: 1.0000 - val_recall: 0.9717
# 58/58 [==============================] - 2s 22ms/step - loss: 0.0157 - accuracy: 0.9967 - precision: 0.9935 - recall: 0.9935
# model_Fold = 1 accuracy: 0.9967391490936279
# model_Fold = 1 precision: 0.9934782385826111
# model_Fold = 1 recall: 0.9934782385826111
# model_Fold = 1 f1_score: 0.9934782385826111
# X_train:  (7360, 178, 1)
# X_val:  (1840, 178, 1)
# y_train:  (7360,)
# y_val:  (1840,)
#
#
# ---- fold = 2 ------
#
# Epoch 1/100
# 230/230 [==============================] - 38s 109ms/step - loss: 0.1667 - accuracy: 0.9348 - precision: 0.8872 - recall: 0.8467 - val_loss: 1.0491 - val_accuracy: 0.8522 - val_precision: 0.6291 - val_recall: 0.9957
# Epoch 2/100
# 230/230 [==============================] - 27s 119ms/step - loss: 0.1135 - accuracy: 0.9587 - precision: 0.9211 - recall: 0.9130 - val_loss: 0.0835 - val_accuracy: 0.9712 - val_precision: 0.9573 - val_recall: 0.9261
# Epoch 3/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0854 - accuracy: 0.9696 - precision: 0.9415 - recall: 0.9364 - val_loss: 0.0994 - val_accuracy: 0.9652 - val_precision: 0.9074 - val_recall: 0.9587
# Epoch 4/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0734 - accuracy: 0.9740 - precision: 0.9493 - recall: 0.9467 - val_loss: 0.2264 - val_accuracy: 0.8897 - val_precision: 0.6980 - val_recall: 0.9848
# Epoch 5/100
# 230/230 [==============================] - 29s 128ms/step - loss: 0.0818 - accuracy: 0.9719 - precision: 0.9464 - recall: 0.9408 - val_loss: 0.0639 - val_accuracy: 0.9837 - val_precision: 0.9799 - val_recall: 0.9543
# Epoch 6/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0623 - accuracy: 0.9791 - precision: 0.9592 - recall: 0.9571 - val_loss: 0.0600 - val_accuracy: 0.9815 - val_precision: 0.9651 - val_recall: 0.9609
# Epoch 7/100
# 230/230 [==============================] - 28s 120ms/step - loss: 0.0721 - accuracy: 0.9749 - precision: 0.9500 - recall: 0.9495 - val_loss: 0.0505 - val_accuracy: 0.9848 - val_precision: 0.9758 - val_recall: 0.9630
# Epoch 8/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0540 - accuracy: 0.9814 - precision: 0.9650 - recall: 0.9603 - val_loss: 0.0506 - val_accuracy: 0.9832 - val_precision: 0.9535 - val_recall: 0.9804
# Epoch 9/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0425 - accuracy: 0.9868 - precision: 0.9744 - recall: 0.9728 - val_loss: 0.0479 - val_accuracy: 0.9821 - val_precision: 0.9713 - val_recall: 0.9565
# Epoch 10/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0446 - accuracy: 0.9844 - precision: 0.9665 - recall: 0.9712 - val_loss: 0.0606 - val_accuracy: 0.9707 - val_precision: 0.9028 - val_recall: 0.9891
# Epoch 11/100
# 230/230 [==============================] - 27s 117ms/step - loss: 0.0345 - accuracy: 0.9872 - precision: 0.9694 - recall: 0.9799 - val_loss: 0.0309 - val_accuracy: 0.9908 - val_precision: 0.9805 - val_recall: 0.9826
# Epoch 12/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0310 - accuracy: 0.9893 - precision: 0.9762 - recall: 0.9810 - val_loss: 0.0449 - val_accuracy: 0.9859 - val_precision: 0.9677 - val_recall: 0.9761
# Epoch 13/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0363 - accuracy: 0.9890 - precision: 0.9751 - recall: 0.9810 - val_loss: 0.0943 - val_accuracy: 0.9891 - val_precision: 0.9955 - val_recall: 0.9609
# Epoch 14/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0397 - accuracy: 0.9856 - precision: 0.9727 - recall: 0.9696 - val_loss: 0.0371 - val_accuracy: 0.9864 - val_precision: 0.9780 - val_recall: 0.9674
# Epoch 15/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0298 - accuracy: 0.9893 - precision: 0.9804 - recall: 0.9766 - val_loss: 0.0297 - val_accuracy: 0.9880 - val_precision: 0.9782 - val_recall: 0.9739
# Epoch 16/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0347 - accuracy: 0.9890 - precision: 0.9803 - recall: 0.9755 - val_loss: 0.0543 - val_accuracy: 0.9810 - val_precision: 0.9474 - val_recall: 0.9783
# Epoch 17/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0362 - accuracy: 0.9894 - precision: 0.9804 - recall: 0.9772 - val_loss: 0.0571 - val_accuracy: 0.9821 - val_precision: 0.9514 - val_recall: 0.9783
# Epoch 18/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0288 - accuracy: 0.9906 - precision: 0.9815 - recall: 0.9810 - val_loss: 0.0370 - val_accuracy: 0.9870 - val_precision: 0.9844 - val_recall: 0.9630
# Epoch 19/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0304 - accuracy: 0.9887 - precision: 0.9787 - recall: 0.9761 - val_loss: 0.0320 - val_accuracy: 0.9870 - val_precision: 0.9760 - val_recall: 0.9717
# Epoch 20/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0253 - accuracy: 0.9916 - precision: 0.9837 - recall: 0.9826 - val_loss: 0.0301 - val_accuracy: 0.9908 - val_precision: 0.9890 - val_recall: 0.9739
# Epoch 21/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0136 - accuracy: 0.9955 - precision: 0.9924 - recall: 0.9897 - val_loss: 0.0355 - val_accuracy: 0.9902 - val_precision: 0.9784 - val_recall: 0.9826
# Epoch 22/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0177 - accuracy: 0.9942 - precision: 0.9875 - recall: 0.9891 - val_loss: 0.0552 - val_accuracy: 0.9793 - val_precision: 0.9306 - val_recall: 0.9913
# Epoch 23/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0206 - accuracy: 0.9928 - precision: 0.9859 - recall: 0.9853 - val_loss: 0.0346 - val_accuracy: 0.9902 - val_precision: 0.9763 - val_recall: 0.9848
# Epoch 24/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0110 - accuracy: 0.9963 - precision: 0.9940 - recall: 0.9913 - val_loss: 0.0316 - val_accuracy: 0.9908 - val_precision: 0.9805 - val_recall: 0.9826
# Epoch 25/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0178 - accuracy: 0.9935 - precision: 0.9875 - recall: 0.9864 - val_loss: 0.0397 - val_accuracy: 0.9908 - val_precision: 0.9933 - val_recall: 0.9696
# Epoch 26/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0183 - accuracy: 0.9932 - precision: 0.9854 - recall: 0.9875 - val_loss: 0.0368 - val_accuracy: 0.9875 - val_precision: 0.9619 - val_recall: 0.9891
# Epoch 27/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0155 - accuracy: 0.9947 - precision: 0.9881 - recall: 0.9908 - val_loss: 0.0698 - val_accuracy: 0.9897 - val_precision: 0.9955 - val_recall: 0.9630
# Epoch 28/100
# 230/230 [==============================] - 27s 118ms/step - loss: 0.0155 - accuracy: 0.9948 - precision: 0.9870 - recall: 0.9924 - val_loss: 0.0288 - val_accuracy: 0.9924 - val_precision: 0.9869 - val_recall: 0.9826
# Epoch 29/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0068 - accuracy: 0.9980 - precision: 0.9978 - recall: 0.9940 - val_loss: 0.0438 - val_accuracy: 0.9902 - val_precision: 0.9955 - val_recall: 0.9652
# Epoch 30/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0130 - accuracy: 0.9963 - precision: 0.9919 - recall: 0.9935 - val_loss: 0.0511 - val_accuracy: 0.9859 - val_precision: 0.9578 - val_recall: 0.9870
# Epoch 31/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0191 - accuracy: 0.9939 - precision: 0.9870 - recall: 0.9886 - val_loss: 0.1421 - val_accuracy: 0.9533 - val_precision: 0.8528 - val_recall: 0.9826
# Epoch 32/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0176 - accuracy: 0.9947 - precision: 0.9875 - recall: 0.9913 - val_loss: 0.0542 - val_accuracy: 0.9870 - val_precision: 0.9955 - val_recall: 0.9522
# Epoch 33/100
# 230/230 [==============================] - 28s 122ms/step - loss: 0.0082 - accuracy: 0.9974 - precision: 0.9940 - recall: 0.9957 - val_loss: 0.0279 - val_accuracy: 0.9929 - val_precision: 0.9934 - val_recall: 0.9783
# Epoch 34/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0074 - accuracy: 0.9974 - precision: 0.9946 - recall: 0.9951 - val_loss: 0.0462 - val_accuracy: 0.9891 - val_precision: 0.9955 - val_recall: 0.9609
# Epoch 35/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0086 - accuracy: 0.9976 - precision: 0.9940 - recall: 0.9962 - val_loss: 0.0807 - val_accuracy: 0.9864 - val_precision: 0.9977 - val_recall: 0.9478
# Epoch 36/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0185 - accuracy: 0.9940 - precision: 0.9865 - recall: 0.9897 - val_loss: 0.0364 - val_accuracy: 0.9870 - val_precision: 0.9599 - val_recall: 0.9891
# Epoch 37/100
# 230/230 [==============================] - 26s 113ms/step - loss: 0.0053 - accuracy: 0.9981 - precision: 0.9962 - recall: 0.9962 - val_loss: 0.0360 - val_accuracy: 0.9951 - val_precision: 0.9934 - val_recall: 0.9870
# Epoch 38/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0153 - accuracy: 0.9951 - precision: 0.9908 - recall: 0.9897 - val_loss: 0.0970 - val_accuracy: 0.9685 - val_precision: 0.8941 - val_recall: 0.9913
# Epoch 39/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0136 - accuracy: 0.9957 - precision: 0.9908 - recall: 0.9918 - val_loss: 0.0352 - val_accuracy: 0.9897 - val_precision: 0.9889 - val_recall: 0.9696
# Epoch 40/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0083 - accuracy: 0.9980 - precision: 0.9951 - recall: 0.9967 - val_loss: 0.0262 - val_accuracy: 0.9924 - val_precision: 0.9912 - val_recall: 0.9783
# Epoch 41/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0052 - accuracy: 0.9980 - precision: 0.9957 - recall: 0.9962 - val_loss: 0.0561 - val_accuracy: 0.9864 - val_precision: 0.9977 - val_recall: 0.9478
# Epoch 42/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0040 - accuracy: 0.9985 - precision: 0.9962 - recall: 0.9978 - val_loss: 0.0342 - val_accuracy: 0.9940 - val_precision: 0.9934 - val_recall: 0.9826
# Epoch 43/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0090 - accuracy: 0.9969 - precision: 0.9919 - recall: 0.9957 - val_loss: 0.0683 - val_accuracy: 0.9842 - val_precision: 0.9716 - val_recall: 0.9652
# Epoch 44/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0088 - accuracy: 0.9974 - precision: 0.9940 - recall: 0.9957 - val_loss: 0.0302 - val_accuracy: 0.9935 - val_precision: 0.9934 - val_recall: 0.9804
# Epoch 45/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0145 - accuracy: 0.9966 - precision: 0.9919 - recall: 0.9946 - val_loss: 0.0344 - val_accuracy: 0.9891 - val_precision: 0.9762 - val_recall: 0.9804
# Epoch 46/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0040 - accuracy: 0.9990 - precision: 0.9973 - recall: 0.9989 - val_loss: 0.0301 - val_accuracy: 0.9935 - val_precision: 0.9891 - val_recall: 0.9848
# Epoch 47/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0032 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9978 - val_loss: 0.0490 - val_accuracy: 0.9891 - val_precision: 0.9889 - val_recall: 0.9674
# Epoch 48/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0190 - accuracy: 0.9937 - precision: 0.9880 - recall: 0.9870 - val_loss: 0.0296 - val_accuracy: 0.9940 - val_precision: 0.9912 - val_recall: 0.9848
# Epoch 49/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0032 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - val_loss: 0.0402 - val_accuracy: 0.9935 - val_precision: 0.9934 - val_recall: 0.9804
# Epoch 50/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0012 - accuracy: 0.9996 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0661 - val_accuracy: 0.9880 - val_precision: 0.9955 - val_recall: 0.9565
# Epoch 51/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0074 - accuracy: 0.9982 - precision: 0.9962 - recall: 0.9967 - val_loss: 0.0269 - val_accuracy: 0.9940 - val_precision: 0.9934 - val_recall: 0.9826
# Epoch 52/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0070 - accuracy: 0.9976 - precision: 0.9940 - recall: 0.9962 - val_loss: 0.0398 - val_accuracy: 0.9842 - val_precision: 0.9462 - val_recall: 0.9935
# Epoch 53/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0041 - accuracy: 0.9981 - precision: 0.9951 - recall: 0.9973 - val_loss: 0.0258 - val_accuracy: 0.9929 - val_precision: 0.9848 - val_recall: 0.9870
# Epoch 54/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0085 - accuracy: 0.9974 - precision: 0.9930 - recall: 0.9967 - val_loss: 0.0323 - val_accuracy: 0.9918 - val_precision: 0.9890 - val_recall: 0.9783
# Epoch 55/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0050 - accuracy: 0.9990 - precision: 0.9973 - recall: 0.9989 - val_loss: 0.0284 - val_accuracy: 0.9946 - val_precision: 0.9978 - val_recall: 0.9804
# Epoch 56/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0060 - accuracy: 0.9982 - precision: 0.9962 - recall: 0.9967 - val_loss: 0.0311 - val_accuracy: 0.9918 - val_precision: 0.9912 - val_recall: 0.9761
# Epoch 57/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0047 - accuracy: 0.9988 - precision: 0.9973 - recall: 0.9978 - val_loss: 0.0282 - val_accuracy: 0.9935 - val_precision: 0.9891 - val_recall: 0.9848
# Epoch 58/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0061 - accuracy: 0.9981 - precision: 0.9957 - recall: 0.9967 - val_loss: 0.0421 - val_accuracy: 0.9902 - val_precision: 1.0000 - val_recall: 0.9609
# Epoch 59/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0021 - accuracy: 0.9997 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0385 - val_accuracy: 0.9918 - val_precision: 0.9869 - val_recall: 0.9804
# Epoch 60/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0018 - accuracy: 0.9993 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0383 - val_accuracy: 0.9935 - val_precision: 0.9912 - val_recall: 0.9826
# Epoch 61/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0246 - accuracy: 0.9921 - precision: 0.9864 - recall: 0.9821 - val_loss: 0.0275 - val_accuracy: 0.9935 - val_precision: 0.9978 - val_recall: 0.9761
# Epoch 62/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0033 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9973 - val_loss: 0.0651 - val_accuracy: 0.9826 - val_precision: 0.9421 - val_recall: 0.9913
# Epoch 63/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0036 - accuracy: 0.9992 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0311 - val_accuracy: 0.9951 - val_precision: 0.9913 - val_recall: 0.9891
# Epoch 64/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0167 - accuracy: 0.9966 - precision: 0.9924 - recall: 0.9940 - val_loss: 0.0320 - val_accuracy: 0.9924 - val_precision: 0.9890 - val_recall: 0.9804
# Epoch 65/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0039 - accuracy: 0.9988 - precision: 0.9973 - recall: 0.9978 - val_loss: 0.0435 - val_accuracy: 0.9902 - val_precision: 0.9889 - val_recall: 0.9717
# Epoch 66/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0099 - accuracy: 0.9981 - precision: 0.9962 - recall: 0.9962 - val_loss: 0.0289 - val_accuracy: 0.9935 - val_precision: 0.9956 - val_recall: 0.9783
# Epoch 67/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0027 - accuracy: 0.9992 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0419 - val_accuracy: 0.9908 - val_precision: 0.9784 - val_recall: 0.9848
# Epoch 68/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0049 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - val_loss: 0.0263 - val_accuracy: 0.9951 - val_precision: 0.9934 - val_recall: 0.9870
# Epoch 69/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0080 - accuracy: 0.9992 - precision: 0.9967 - recall: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9918 - val_precision: 0.9978 - val_recall: 0.9696
# Epoch 70/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0080 - accuracy: 0.9971 - precision: 0.9940 - recall: 0.9946 - val_loss: 0.0287 - val_accuracy: 0.9924 - val_precision: 0.9806 - val_recall: 0.9891
# Epoch 71/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0061 - accuracy: 0.9978 - precision: 0.9951 - recall: 0.9962 - val_loss: 0.0968 - val_accuracy: 0.9875 - val_precision: 1.0000 - val_recall: 0.9500
# Epoch 72/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0038 - accuracy: 0.9988 - precision: 0.9973 - recall: 0.9978 - val_loss: 0.0338 - val_accuracy: 0.9940 - val_precision: 0.9849 - val_recall: 0.9913
# Epoch 73/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0143 - accuracy: 0.9980 - precision: 0.9935 - recall: 0.9984 - val_loss: 0.0715 - val_accuracy: 0.9859 - val_precision: 0.9801 - val_recall: 0.9630
# Epoch 74/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0053 - accuracy: 0.9988 - precision: 0.9978 - recall: 0.9973 - val_loss: 0.0310 - val_accuracy: 0.9946 - val_precision: 0.9891 - val_recall: 0.9891
# Epoch 75/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0068 - accuracy: 0.9984 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.0246 - val_accuracy: 0.9924 - val_precision: 0.9827 - val_recall: 0.9870
# Epoch 76/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0019 - accuracy: 0.9995 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0309 - val_accuracy: 0.9946 - val_precision: 0.9934 - val_recall: 0.9848
# Epoch 77/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0073 - accuracy: 0.9988 - precision: 0.9973 - recall: 0.9978 - val_loss: 0.0323 - val_accuracy: 0.9924 - val_precision: 0.9827 - val_recall: 0.9870
# Epoch 78/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0062 - accuracy: 0.9988 - precision: 0.9973 - recall: 0.9978 - val_loss: 0.0295 - val_accuracy: 0.9935 - val_precision: 0.9891 - val_recall: 0.9848
# Epoch 79/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0038 - accuracy: 0.9984 - precision: 0.9962 - recall: 0.9973 - val_loss: 0.0311 - val_accuracy: 0.9946 - val_precision: 0.9978 - val_recall: 0.9804
# Epoch 80/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0018 - accuracy: 0.9993 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0250 - val_accuracy: 0.9951 - val_precision: 0.9934 - val_recall: 0.9870
# Epoch 81/100
# 230/230 [==============================] - 18s 79ms/step - loss: 5.8246e-04 - accuracy: 0.9999 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9946 - val_precision: 0.9978 - val_recall: 0.9804
# Epoch 82/100
# 230/230 [==============================] - 18s 80ms/step - loss: 4.8972e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9946 - val_precision: 0.9956 - val_recall: 0.9826
# Epoch 83/100
# 230/230 [==============================] - 18s 79ms/step - loss: 8.2163e-04 - accuracy: 0.9999 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9951 - val_precision: 0.9934 - val_recall: 0.9870
# Epoch 84/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0025 - accuracy: 0.9990 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0263 - val_accuracy: 0.9946 - val_precision: 0.9934 - val_recall: 0.9848
# Epoch 85/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0018 - accuracy: 0.9997 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0437 - val_accuracy: 0.9908 - val_precision: 0.9933 - val_recall: 0.9696
# Epoch 86/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0021 - accuracy: 0.9995 - precision: 0.9984 - recall: 0.9995 - val_loss: 0.0541 - val_accuracy: 0.9891 - val_precision: 0.9955 - val_recall: 0.9609
# Epoch 87/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0099 - accuracy: 0.9976 - precision: 0.9967 - recall: 0.9935 - val_loss: 0.0227 - val_accuracy: 0.9940 - val_precision: 0.9934 - val_recall: 0.9826
# Epoch 88/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0037 - accuracy: 0.9992 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0334 - val_accuracy: 0.9929 - val_precision: 0.9848 - val_recall: 0.9870
# Epoch 89/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0023 - accuracy: 0.9990 - precision: 0.9984 - recall: 0.9978 - val_loss: 0.0320 - val_accuracy: 0.9951 - val_precision: 0.9978 - val_recall: 0.9826
# Epoch 90/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0069 - accuracy: 0.9980 - precision: 0.9967 - recall: 0.9951 - val_loss: 0.0195 - val_accuracy: 0.9940 - val_precision: 1.0000 - val_recall: 0.9761
# Epoch 91/100
# 230/230 [==============================] - 18s 79ms/step - loss: 8.5069e-04 - accuracy: 0.9999 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9951 - val_precision: 0.9978 - val_recall: 0.9826
# Epoch 92/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0076 - accuracy: 0.9982 - precision: 0.9951 - recall: 0.9978 - val_loss: 0.0298 - val_accuracy: 0.9951 - val_precision: 0.9934 - val_recall: 0.9870
# Epoch 93/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0014 - accuracy: 0.9995 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0358 - val_accuracy: 0.9929 - val_precision: 0.9891 - val_recall: 0.9826
# Epoch 94/100
# 230/230 [==============================] - 18s 79ms/step - loss: 8.6698e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9935 - val_precision: 0.9912 - val_recall: 0.9826
# Epoch 95/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.1544e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9940 - val_precision: 0.9912 - val_recall: 0.9848
# Epoch 96/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.6292e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9946 - val_precision: 0.9978 - val_recall: 0.9804
# Epoch 97/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.7651e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0470 - val_accuracy: 0.9940 - val_precision: 0.9978 - val_recall: 0.9783
# Epoch 98/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0044 - accuracy: 0.9988 - precision: 0.9967 - recall: 0.9984 - val_loss: 0.0333 - val_accuracy: 0.9913 - val_precision: 0.9868 - val_recall: 0.9783
# Epoch 99/100
# 230/230 [==============================] - 18s 78ms/step - loss: 2.9301e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9940 - val_precision: 0.9870 - val_recall: 0.9891
# Epoch 100/100
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0142 - accuracy: 0.9973 - precision: 0.9935 - recall: 0.9957 - val_loss: 0.0204 - val_accuracy: 0.9951 - val_precision: 0.9978 - val_recall: 0.9826
# 58/58 [==============================] - 2s 24ms/step - loss: 0.0360 - accuracy: 0.9951 - precision: 0.9934 - recall: 0.9870
# model_Fold = 2 accuracy: 0.9951087236404419
# model_Fold = 2 precision: 0.9934354424476624
# model_Fold = 2 recall: 0.9869565367698669
# model_Fold = 2 f1_score: 0.9901853916515869
# X_train:  (7360, 178, 1)
# X_val:  (1840, 178, 1)
# y_train:  (7360,)
# y_val:  (1840,)
#
#
# ---- fold = 3 ------
#
# Epoch 1/100
# 230/230 [==============================] - 37s 101ms/step - loss: 0.1548 - accuracy: 0.9391 - precision: 0.8897 - recall: 0.8636 - val_loss: 0.2278 - val_accuracy: 0.9092 - val_precision: 0.7367 - val_recall: 0.9913
# Epoch 2/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.1071 - accuracy: 0.9621 - precision: 0.9300 - recall: 0.9174 - val_loss: 0.3956 - val_accuracy: 0.8283 - val_precision: 0.5938 - val_recall: 0.9913
# Epoch 3/100
# 230/230 [==============================] - 27s 119ms/step - loss: 0.0907 - accuracy: 0.9654 - precision: 0.9366 - recall: 0.9239 - val_loss: 0.1466 - val_accuracy: 0.9587 - val_precision: 0.8664 - val_recall: 0.9870
# Epoch 4/100
# 230/230 [==============================] - 19s 80ms/step - loss: 0.0748 - accuracy: 0.9743 - precision: 0.9469 - recall: 0.9505 - val_loss: 0.1245 - val_accuracy: 0.9533 - val_precision: 0.8528 - val_recall: 0.9826
# Epoch 5/100
# 230/230 [==============================] - 27s 120ms/step - loss: 0.0668 - accuracy: 0.9764 - precision: 0.9517 - recall: 0.9538 - val_loss: 0.0587 - val_accuracy: 0.9853 - val_precision: 0.9887 - val_recall: 0.9522
# Epoch 6/100
# 230/230 [==============================] - 19s 81ms/step - loss: 0.0726 - accuracy: 0.9758 - precision: 0.9511 - recall: 0.9522 - val_loss: 0.0655 - val_accuracy: 0.9761 - val_precision: 0.9211 - val_recall: 0.9891
# Epoch 7/100
# ...
# Epoch 28/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0104 - accuracy: 0.9966 - precision: 0.9935 - recall: 0.9929 - val_loss: 0.0238 - val_accuracy: 0.9918 - val_precision: 0.9806 - val_recall: 0.9870
# Epoch 29/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0224 - accuracy: 0.9918 - precision: 0.9832 - recall: 0.9842 - val_loss: 0.0454 - val_accuracy: 0.9842 - val_precision: 0.9443 - val_recall: 0.9957
# Epoch 30/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0071 - accuracy: 0.9976 - precision: 0.9940 - recall: 0.9962 - val_loss: 0.0447 - val_accuracy: 0.9918 - val_precision: 0.9955 - val_recall: 0.9717
# Epoch 31/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0179 - accuracy: 0.9939 - precision: 0.9843 - recall: 0.9913 - val_loss: 0.0508 - val_accuracy: 0.9886 - val_precision: 0.9782 - val_recall: 0.9761
# Epoch 32/100
# 230/230 [==============================] - 28s 121ms/step - loss: 0.0174 - accuracy: 0.9951 - precision: 0.9908 - recall: 0.9897 - val_loss: 0.0167 - val_accuracy: 0.9946 - val_precision: 0.9891 - val_recall: 0.9891
# Epoch 33/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0151 - accuracy: 0.9951 - precision: 0.9908 - recall: 0.9897 - val_loss: 0.0197 - val_accuracy: 0.9924 - val_precision: 0.9890 - val_recall: 0.9804
# Epoch 34/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0099 - accuracy: 0.9969 - precision: 0.9940 - recall: 0.9935 - val_loss: 0.0272 - val_accuracy: 0.9935 - val_precision: 0.9978 - val_recall: 0.9761
# Epoch 35/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0062 - accuracy: 0.9980 - precision: 0.9962 - recall: 0.9957 - val_loss: 0.0376 - val_accuracy: 0.9880 - val_precision: 0.9740 - val_recall: 0.9783
# Epoch 36/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0103 - accuracy: 0.9965 - precision: 0.9924 - recall: 0.9935 - val_loss: 0.0350 - val_accuracy: 0.9891 - val_precision: 0.9622 - val_recall: 0.9957
# Epoch 37/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0086 - accuracy: 0.9970 - precision: 0.9946 - recall: 0.9935 - val_loss: 0.0322 - val_accuracy: 0.9880 - val_precision: 0.9932 - val_recall: 0.9587
# Epoch 38/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0099 - accuracy: 0.9971 - precision: 0.9940 - recall: 0.9946 - val_loss: 0.0443 - val_accuracy: 0.9902 - val_precision: 0.9804 - val_recall: 0.9804
# Epoch 39/100
# 230/230 [==============================] - 27s 117ms/step - loss: 0.0236 - accuracy: 0.9925 - precision: 0.9822 - recall: 0.9880 - val_loss: 0.0133 - val_accuracy: 0.9967 - val_precision: 0.9956 - val_recall: 0.9913
# Epoch 40/100
# 230/230 [==============================] - 19s 81ms/step - loss: 0.0112 - accuracy: 0.9958 - precision: 0.9908 - recall: 0.9924 - val_loss: 0.0168 - val_accuracy: 0.9962 - val_precision: 0.9978 - val_recall: 0.9870
# Epoch 41/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0068 - accuracy: 0.9974 - precision: 0.9946 - recall: 0.9951 - val_loss: 0.0139 - val_accuracy: 0.9957 - val_precision: 0.9892 - val_recall: 0.9935
# Epoch 42/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0053 - accuracy: 0.9978 - precision: 0.9957 - recall: 0.9957 - val_loss: 0.0189 - val_accuracy: 0.9940 - val_precision: 0.9891 - val_recall: 0.9870
# Epoch 43/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0059 - accuracy: 0.9976 - precision: 0.9935 - recall: 0.9967 - val_loss: 0.0357 - val_accuracy: 0.9897 - val_precision: 0.9977 - val_recall: 0.9609
# Epoch 44/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0089 - accuracy: 0.9973 - precision: 0.9935 - recall: 0.9957 - val_loss: 0.0250 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9696
# Epoch 45/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0070 - accuracy: 0.9981 - precision: 0.9957 - recall: 0.9967 - val_loss: 0.0316 - val_accuracy: 0.9891 - val_precision: 0.9681 - val_recall: 0.9891
# Epoch 46/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0023 - accuracy: 0.9993 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0111 - val_accuracy: 0.9962 - val_precision: 0.9935 - val_recall: 0.9913
# Epoch 47/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0188 - accuracy: 0.9950 - precision: 0.9881 - recall: 0.9918 - val_loss: 0.0231 - val_accuracy: 0.9935 - val_precision: 0.9956 - val_recall: 0.9783
# Epoch 48/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0195 - accuracy: 0.9946 - precision: 0.9870 - recall: 0.9913 - val_loss: 0.0459 - val_accuracy: 0.9880 - val_precision: 0.9761 - val_recall: 0.9761
# Epoch 49/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0065 - accuracy: 0.9976 - precision: 0.9940 - recall: 0.9962 - val_loss: 0.0191 - val_accuracy: 0.9929 - val_precision: 0.9891 - val_recall: 0.9826
# Epoch 50/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0033 - accuracy: 0.9984 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.0256 - val_accuracy: 0.9935 - val_precision: 0.9848 - val_recall: 0.9891
# Epoch 51/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0083 - accuracy: 0.9981 - precision: 0.9951 - recall: 0.9973 - val_loss: 0.0156 - val_accuracy: 0.9935 - val_precision: 0.9848 - val_recall: 0.9891
# Epoch 52/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0077 - accuracy: 0.9976 - precision: 0.9956 - recall: 0.9946 - val_loss: 0.0195 - val_accuracy: 0.9957 - val_precision: 0.9956 - val_recall: 0.9870
# Epoch 53/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0055 - accuracy: 0.9982 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.0217 - val_accuracy: 0.9935 - val_precision: 0.9870 - val_recall: 0.9870
# Epoch 54/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0103 - accuracy: 0.9967 - precision: 0.9908 - recall: 0.9962 - val_loss: 0.0187 - val_accuracy: 0.9935 - val_precision: 0.9848 - val_recall: 0.9891
# Epoch 55/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0129 - accuracy: 0.9958 - precision: 0.9924 - recall: 0.9908 - val_loss: 0.0281 - val_accuracy: 0.9913 - val_precision: 0.9744 - val_recall: 0.9913
# Epoch 56/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0074 - accuracy: 0.9977 - precision: 0.9951 - recall: 0.9957 - val_loss: 0.0186 - val_accuracy: 0.9940 - val_precision: 0.9978 - val_recall: 0.9783
# Epoch 57/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0053 - accuracy: 0.9980 - precision: 0.9967 - recall: 0.9951 - val_loss: 0.0232 - val_accuracy: 0.9918 - val_precision: 0.9806 - val_recall: 0.9870
# Epoch 58/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0136 - accuracy: 0.9954 - precision: 0.9876 - recall: 0.9940 - val_loss: 0.0187 - val_accuracy: 0.9951 - val_precision: 0.9913 - val_recall: 0.9891
# Epoch 59/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0092 - accuracy: 0.9982 - precision: 0.9951 - recall: 0.9978 - val_loss: 0.0214 - val_accuracy: 0.9924 - val_precision: 0.9934 - val_recall: 0.9761
# Epoch 60/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0042 - accuracy: 0.9990 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0172 - val_accuracy: 0.9951 - val_precision: 0.9956 - val_recall: 0.9848
# Epoch 61/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0024 - accuracy: 0.9993 - precision: 0.9978 - recall: 0.9995 - val_loss: 0.0216 - val_accuracy: 0.9940 - val_precision: 0.9912 - val_recall: 0.9848
# Epoch 62/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0032 - accuracy: 0.9988 - precision: 0.9978 - recall: 0.9973 - val_loss: 0.0241 - val_accuracy: 0.9924 - val_precision: 0.9806 - val_recall: 0.9891
# Epoch 63/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0018 - accuracy: 0.9996 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0184 - val_accuracy: 0.9946 - val_precision: 0.9913 - val_recall: 0.9870
# Epoch 64/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0093 - accuracy: 0.9976 - precision: 0.9946 - recall: 0.9957 - val_loss: 0.0206 - val_accuracy: 0.9951 - val_precision: 0.9913 - val_recall: 0.9891
# Epoch 65/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0056 - accuracy: 0.9985 - precision: 0.9973 - recall: 0.9967 - val_loss: 0.0182 - val_accuracy: 0.9929 - val_precision: 1.0000 - val_recall: 0.9717
# Epoch 66/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0015 - accuracy: 0.9996 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0257 - val_accuracy: 0.9913 - val_precision: 0.9912 - val_recall: 0.9739
# Epoch 67/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0072 - accuracy: 0.9978 - precision: 0.9957 - recall: 0.9957 - val_loss: 0.0147 - val_accuracy: 0.9946 - val_precision: 0.9849 - val_recall: 0.9935
# Epoch 68/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0030 - accuracy: 0.9995 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0138 - val_accuracy: 0.9957 - val_precision: 0.9913 - val_recall: 0.9913
# Epoch 69/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0043 - accuracy: 0.9988 - precision: 0.9967 - recall: 0.9984 - val_loss: 0.0283 - val_accuracy: 0.9935 - val_precision: 0.9934 - val_recall: 0.9804
# Epoch 70/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0068 - accuracy: 0.9980 - precision: 0.9946 - recall: 0.9973 - val_loss: 0.0207 - val_accuracy: 0.9929 - val_precision: 0.9848 - val_recall: 0.9870
# Epoch 71/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0022 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9984 - val_loss: 0.0157 - val_accuracy: 0.9957 - val_precision: 0.9871 - val_recall: 0.9957
# Epoch 72/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0024 - accuracy: 0.9992 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0166 - val_accuracy: 0.9962 - val_precision: 0.9913 - val_recall: 0.9935
# Epoch 73/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0071 - accuracy: 0.9985 - precision: 0.9973 - recall: 0.9967 - val_loss: 0.1022 - val_accuracy: 0.9891 - val_precision: 0.9622 - val_recall: 0.9957
# Epoch 74/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0137 - accuracy: 0.9966 - precision: 0.9962 - recall: 0.9902 - val_loss: 0.0203 - val_accuracy: 0.9962 - val_precision: 0.9913 - val_recall: 0.9935
# Epoch 75/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0056 - accuracy: 0.9989 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0356 - val_accuracy: 0.9902 - val_precision: 0.9742 - val_recall: 0.9870
# Epoch 76/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0198 - accuracy: 0.9936 - precision: 0.9870 - recall: 0.9875 - val_loss: 0.0150 - val_accuracy: 0.9957 - val_precision: 0.9913 - val_recall: 0.9913
# Epoch 77/100
# 230/230 [==============================] - 18s 79ms/step - loss: 6.9436e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9957 - val_precision: 0.9913 - val_recall: 0.9913
# Epoch 78/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0017 - accuracy: 0.9992 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0186 - val_accuracy: 0.9951 - val_precision: 0.9892 - val_recall: 0.9913
# Epoch 79/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0034 - accuracy: 0.9992 - precision: 0.9978 - recall: 0.9989 - val_loss: 0.0213 - val_accuracy: 0.9951 - val_precision: 0.9934 - val_recall: 0.9870
# Epoch 80/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0050 - accuracy: 0.9989 - precision: 0.9978 - recall: 0.9978 - val_loss: 0.0372 - val_accuracy: 0.9886 - val_precision: 0.9933 - val_recall: 0.9609
# Epoch 81/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0029 - accuracy: 0.9989 - precision: 0.9973 - recall: 0.9984 - val_loss: 0.0248 - val_accuracy: 0.9946 - val_precision: 0.9934 - val_recall: 0.9848
# Epoch 82/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0020 - accuracy: 0.9993 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0269 - val_accuracy: 0.9935 - val_precision: 0.9807 - val_recall: 0.9935
# Epoch 83/100
# 230/230 [==============================] - 18s 79ms/step - loss: 7.5982e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9940 - val_precision: 0.9828 - val_recall: 0.9935
# Epoch 84/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0029 - accuracy: 0.9990 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0187 - val_accuracy: 0.9935 - val_precision: 0.9870 - val_recall: 0.9870
# Epoch 85/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0063 - accuracy: 0.9985 - precision: 0.9967 - recall: 0.9973 - val_loss: 0.0331 - val_accuracy: 0.9918 - val_precision: 0.9912 - val_recall: 0.9761
# Epoch 86/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0065 - accuracy: 0.9971 - precision: 0.9951 - recall: 0.9935 - val_loss: 0.0164 - val_accuracy: 0.9940 - val_precision: 0.9828 - val_recall: 0.9935
# Epoch 87/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0170 - val_accuracy: 0.9946 - val_precision: 0.9849 - val_recall: 0.9935
# Epoch 88/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0034 - accuracy: 0.9993 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0307 - val_accuracy: 0.9908 - val_precision: 0.9847 - val_recall: 0.9783
# Epoch 89/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0048 - accuracy: 0.9990 - precision: 0.9984 - recall: 0.9978 - val_loss: 0.0220 - val_accuracy: 0.9957 - val_precision: 0.9913 - val_recall: 0.9913
# Epoch 90/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0013 - accuracy: 0.9999 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9962 - val_precision: 0.9892 - val_recall: 0.9957
# Epoch 91/100
# 230/230 [==============================] - 18s 80ms/step - loss: 9.3183e-04 - accuracy: 0.9996 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0350 - val_accuracy: 0.9924 - val_precision: 0.9785 - val_recall: 0.9913
# Epoch 92/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0072 - accuracy: 0.9980 - precision: 0.9967 - recall: 0.9951 - val_loss: 0.0195 - val_accuracy: 0.9951 - val_precision: 0.9913 - val_recall: 0.9891
# Epoch 93/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.4564e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9946 - val_precision: 0.9934 - val_recall: 0.9848
# Epoch 94/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8431e-04 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0300 - val_accuracy: 0.9951 - val_precision: 0.9913 - val_recall: 0.9891
# Epoch 95/100
# 230/230 [==============================] - 18s 79ms/step - loss: 4.0003e-04 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0350 - val_accuracy: 0.9929 - val_precision: 0.9765 - val_recall: 0.9957
# Epoch 96/100
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0059 - accuracy: 0.9984 - precision: 0.9957 - recall: 0.9978 - val_loss: 0.0148 - val_accuracy: 0.9957 - val_precision: 0.9956 - val_recall: 0.9870
# Epoch 97/100
#  20/230 [=>............................] - ETA: 15s - loss: 0.0091 - accuracy: 0.9969 - precision: 0.9934 - recall: 0.9934

# %%
0.9967391490936279 + 0.9951087236404419 + 0.9967391490936279 + 0.9934782385826111 + 0.9962
