# %% [markdown]
# ## Investigating the Impact of Residual Connection to Convolutional Layer on EEG Classification Performance

# %% [markdown]
# ### Experiment Summary:
#
# **This experiment aims to explore the influence of residual connection with convolutional layers on the performance of EEG classification models. We investigate the relationship between the number of convolutional layers and the resulting accuracy.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %mkdir /content/drive/MyDrive/ED_Experiments
# %mkdir /content/drive/MyDrive/ED_Experiments/ED_CNN_E13

# %%
# %mkdir /content/drive/MyDrive/ED_Experiments/SeizureVsEyesClosed

# %%
# %cd /content/drive/MyDrive/ED_Experiments/SeizureVsEyesClosed
# %ls
# Out:
# /content/drive/MyDrive/ED_Experiments/SeizureVsEyesClosed

# %% [markdown]
# ## Import libraries

# %%
import sys
import os
import logging


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, StratifiedKFold

from tqdm import tqdm

import keras
from keras.layers import Dense, Convolution1D, MaxPool1D, Flatten, Dropout
from keras.layers import Input, LSTM
from keras.layers import BatchNormalization
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import metrics

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
## seed
np.random.seed(2023)

# %% [markdown]
# ### Reading CSV data

# %%
raw_data = pd.read_csv('https://raw.githubusercontent.com/mamuncseru/analysis_on_epileptic_seizure_bonn_dataset/main/Epileptic%20Seizure%20Recognition.csv')
raw_data.shape
# Out:
# (11500, 180)

# %%
raw_data
# Out:
#           Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  \
# 0      X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17
# 1      X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164
# 2         X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57
# 3       X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82
# 4       X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 11495  X22.V1.114  -22  -22  -23  -26  -36  -42  -45  -42  -45  ...    15
# 11496  X19.V1.354  -47  -11   28   77  141  211  246  240  193  ...   -65
# 11497    X8.V1.28   14    6  -13  -16   10   26   27   -9    4  ...   -65
# 11498  X10.V1.932  -40  -25   -9  -12   -2   12    7   19   22  ...   121
# 11499  X16.V1.210   29   41   57   72   74   62   54   43   31  ...   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# 0       -15   -31   -77  -103  -127  -116   -83   -51  4
# 1       150   146   152   157   156   154   143   129  1
# 2        64    48    19   -12   -30   -35   -35   -36  5
# 3       -81   -80   -77   -85   -77   -72   -69   -65  5
# 4         2   -12   -32   -41   -65   -83   -89   -73  5
# ...     ...   ...   ...   ...   ...   ...   ...   ... ..
# 11495    16    12     5    -1   -18   -37   -47   -48  2
# 11496   -33    -7    14    27    48    77   117   170  1
# 11497   -48   -61   -62   -67   -30    -2    -1    -8  5
# 11498   135   148   143   116    86    68    59    55  3
# 11499   -25    -4     2     5     4    -2     2    20  4
#
# [11500 rows x 180 columns]

# %%
raw_data.values.shape
# Out:
# (11500, 180)

# %%
data = raw_data.values # converted to an numpy array
data = data[:, 1:] # discarding the Unnamed Column
data.shape
# Out:
# (11500, 179)

# %%
# let's see how it looks like
data
# Out:
# array([[135, 190, 229, ..., -83, -51, 4],
#        [386, 382, 356, ..., 143, 129, 1],
#        [-32, -39, -47, ..., -35, -36, 5],
#        ...,
#        [14, 6, -13, ..., -1, -8, 5],
#        [-40, -25, -9, ..., 59, 55, 3],
#        [29, 41, 57, ..., 2, 20, 4]], dtype=object)

# %%
# let's see the type
type(data)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Classifying data categories as it mentioned in the paper

# %%
df_1 = data[data[:, -1] == 1].astype(int) # seizure
df_2 = data[data[:, -1] == 2].astype(int)
df_3 = data[data[:, -1] == 3].astype(int)
df_4 = data[data[:, -1] == 4].astype(int)
df_5 = data[data[:, -1] == 5].astype(int)

# let's print the shape of each category
print(df_1.shape)
print(df_2.shape)
print(df_3.shape)
print(df_4.shape)
print(df_5.shape)
# Out:
# (2300, 179)
# (2300, 179)
# (2300, 179)
# (2300, 179)
# (2300, 179)

# %% [markdown]
# ## Let's plot some random data points from every category

# %%
def visualize_eeg(number_of_datapoints):
    for i in (np.random.randint(0, 2300, number_of_datapoints)):
        plt.plot(df_1[i, :], 'r-', label='df_1')
        plt.plot(df_4[i, :], 'm-', label='df_4')
        plt.legend()
        plt.title(f'Eyes Closed vs Seizure data visualizing {i} th data point')
        plt.xlabel('time')
        plt.ylabel('aplitude(uV)')
        plt.show()

# %% [markdown]
# ### Visualizing all categories in single figure

# %%
### all categories
visualize_eeg(5)

# %% [markdown]
# ## Converting data into integer and making the data into seizure and non-seizure cateogry

# %%
data = np.concatenate((df_1, df_4))

# %% [markdown]
# ## Plot functions

# %% [markdown]
# ### function to plot loss curve of the
# - (training and validation loss) and
# - (training and validation accuracy)

# %%
def plot_loss_accuracy(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(14, 6))

    ax[0].plot(history.history['loss'], 'b-')
    ax[0].plot(history.history['val_loss'], 'r-')
    ax[0].legend(['train_loss', 'val_loss'])
    ax[0].set_title('Loss curve')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss %')

    ax[1].plot(history.history['accuracy'], 'b-')
    ax[1].plot(history.history['val_accuracy'], 'r-')
    ax[1].legend(['train_accuracy', 'val_accuracy'])
    ax[1].set_title('Accuracy curve')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('accuracy %')

    plt.suptitle(title)
    plt.savefig(title + '_loss_accuracy.png')

    plt.show()

# %%
def plot_precision_recall(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(14, 6))

    ax[0].plot(history.history['precision'], 'b-')
    ax[0].plot(history.history['val_precision'], 'r-')
    ax[0].legend(['train_precision', 'val_precision'])
    ax[0].set_title('precision curve')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Precision %')

    ax[1].plot(history.history['recall'], 'b-')
    ax[1].plot(history.history['val_recall'], 'r-')
    ax[1].legend(['train_recall', 'val_recall'])
    ax[1].set_title('recall curve')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Recall %')

    plt.suptitle(title)
    plt.savefig(title + '_precision_recall.png')

    plt.show()

# %%
# Initialize StratifiedKFold with 5 folds
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=2023)

# %%
def input_output_data(data, random_state=2023):
    data[:, -1] = np.where(data[:, -1] != 1, 0, data[:, -1])

    X = data[:, :-1]
    y = data[:, -1]

    return X, y

X, y = input_output_data(data)

# %%
X.shape
# Out:
# (4600, 178)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
def process_input(X, y, train_index, val_index):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    X_train = np.expand_dims(X_train, axis=2)
    X_val = np.expand_dims(X_val, axis=2)

    input_shape = (X_train.shape[1], 1)

    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')


    return X_train, X_val, y_train, y_val, input_shape

# %% [markdown]
# ## Logger setup

# %%
import absl.logging
import sys
import logging
absl.logging.set_verbosity(absl.logging.ERROR)
absl.logging.set_verbosity(absl.logging.INFO)

# %%
def init_logger(log_file, log_level=logging.INFO, stdout=True):
    logger = logging.getLogger()
    logger.setLevel(log_level)

    formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')

    file_handler = logging.FileHandler(log_file, mode='w')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    if stdout:
        console_handler = logging.StreamHandler(sys.stdout)
        console_handler.setFormatter(formatter)
        logger.addHandler(console_handler)

    return logger

# %% [markdown]
# ## Let's experiment with the Residual Connection

# %%
def residual_block(x, filters, kernel_size, padding='same', activation='relu'):
    shortcut = x
    x = layers.Conv1D(filters=filters, kernel_size=kernel_size, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(activation)(x)
    x = layers.Conv1D(filters=filters, kernel_size=kernel_size, padding=padding)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([shortcut, x])
    x = layers.Activation(activation)(x)
    return x

def create_residual_eeg_model(input_shape):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv1D(filters=128, kernel_size=5, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=128, kernel_size=5)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=256, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=256, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=512, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=512, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=1024, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=1024, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.Conv1D(filters=2048, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = residual_block(x, filters=2048, kernel_size=3)
    x = layers.MaxPooling1D(2, padding='same')(x)

    x = layers.GlobalAveragePooling1D()(x)  # Replace Flatten layer with GlobalAveragePooling1D
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Perform cross-validation
fold_accuracy = []
fold_precision = []
fold_recall = []
fold_f1score = []
fold = 1

for train_index, val_index in skf.split(X, y):
    X_train, X_val, y_train, y_val, input_shape = process_input(X, y, train_index, val_index)
    print('X_train: ', X_train.shape)
    print('X_val: ', X_val.shape)
    print('y_train: ', y_train.shape)
    print('y_val: ', y_val.shape)


    # model = eegClassifier(input_shape)
    model = create_residual_eeg_model(input_shape)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',
                                                                         tf.keras.metrics.Precision(name='precision'),
                                                                         tf.keras.metrics.Recall(name='recall')])
    log_file = f"model_fold_{fold}.log"
    model_name = f"model_fold_{fold}.h5"

    # Clear existing log handlers and close log files
    root_logger = logging.getLogger()
    for handler in root_logger.handlers:
        handler.close()
    root_logger.handlers.clear()

    # Create a separate log file for each model
    logger = init_logger(log_file, stdout=False)


    logger.info(f"\n\n---- fold = {fold} -------\n")
    print(f"\n\n---- fold = {fold} ------\n")

    # Define the checkpoint callback to save the best model
    checkpoint = ModelCheckpoint(model_name, monitor='val_accuracy', save_best_only=True, mode='max', save_format="h5")

    # Train the model and capture the history
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,
                        callbacks=[checkpoint])

    # Log loss and accuracy
    for i, (loss, accuracy, precision, recall) in enumerate(zip(history.history['loss'],
                                                                history.history['accuracy'],
                                                                history.history['precision'],
                                                                history.history['recall'])):
        logger.info(f"Epoch {i+1} - Loss: {loss} - Accuracy: {accuracy} - Precision: {precision} - Recall: {recall}")

    for i, (val_loss, val_accuracy, val_precision, val_recall) in enumerate(zip(history.history['val_loss'],
                                                                                history.history['val_accuracy'],
                                                                                history.history['val_precision'],
                                                                                history.history['val_recall'])):
        logger.info(f"Epoch {i+1} - Validation Loss: {val_loss} - Validation Accuracy: {val_accuracy}")


    # Evaluate the model
    best_model_path = model_name
    best_model = tf.keras.models.load_model(best_model_path)
    loss_scale_optimizer, accuracy, precision, recall = best_model.evaluate(X_val, y_val)
    fold_accuracy.append(accuracy)
    fold_precision.append(precision)
    fold_recall.append(recall)

    # Log fold accuracy
    logger.info(f"model_Fold = {fold} accuracy: {accuracy}")
    logger.info(f"model_Fold = {fold} precision: {precision}")
    logger.info(f"model_Fold = {fold} recall: {recall}")


    print(f"model_Fold = {fold} accuracy: {accuracy}")
    print(f"model_Fold = {fold} precision: {precision}")
    print(f"model_Fold = {fold} recall: {recall}")
    print(f"model_Fold = {fold} f1_score: {2*(precision*recall) / (precision + recall)}")

    plot_loss_accuracy(history, f"model_fold_{fold}")
    plot_precision_recall(history, f"model_fold_{fold}")
    # plot_accuracy(history)

    fold += 1

# Calculate the average accuracy across all folds
mean_accuracy = np.mean(fold_accuracy)
mean_precision = np.mean(fold_precision)
mean_recall = np.mean(fold_recall)
mean_f1_score = 2 * (mean_precision * mean_recall) / (mean_precision + mean_recall)

print("Mean Accuracy:", mean_accuracy)
print("Mean Precision:", mean_precision)
print("Mean Recall:", mean_recall)
print("Mean F1_Score:", mean_f1_score)
# Out:
# X_train:  (3680, 178, 1)
# X_val:  (920, 178, 1)
# y_train:  (3680,)
# y_val:  (920,)
#
#
# ---- fold = 1 ------
#
# Epoch 1/100
# 115/115 [==============================] - 36s 203ms/step - loss: 0.1617 - accuracy: 0.9427 - precision: 0.9502 - recall: 0.9342 - val_loss: 2.6302 - val_accuracy: 0.5717 - val_precision: 0.5386 - val_recall: 1.0000
# Epoch 2/100
# 115/115 [==============================] - 14s 121ms/step - loss: 0.0874 - accuracy: 0.9693 - precision: 0.9763 - recall: 0.9620 - val_loss: 0.0978 - val_accuracy: 0.9522 - val_precision: 0.9127 - val_recall: 1.0000
# Epoch 3/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0591 - accuracy: 0.9791 - precision: 0.9788 - recall: 0.9793 - val_loss: 0.1368 - val_accuracy: 0.9250 - val_precision: 0.8696 - val_recall: 1.0000
# Epoch 4/100
# 115/115 [==============================] - 17s 145ms/step - loss: 0.0381 - accuracy: 0.9867 - precision: 0.9875 - recall: 0.9859 - val_loss: 0.0283 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 5/100
# 115/115 [==============================] - 10s 86ms/step - loss: 0.0459 - accuracy: 0.9848 - precision: 0.9874 - recall: 0.9821 - val_loss: 0.0578 - val_accuracy: 0.9804 - val_precision: 1.0000 - val_recall: 0.9609
# Epoch 6/100
# 115/115 [==============================] - 19s 164ms/step - loss: 0.0403 - accuracy: 0.9856 - precision: 0.9875 - recall: 0.9837 - val_loss: 0.0154 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 7/100
# 115/115 [==============================] - 15s 129ms/step - loss: 0.0324 - accuracy: 0.9880 - precision: 0.9886 - recall: 0.9875 - val_loss: 0.0165 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 8/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0278 - accuracy: 0.9889 - precision: 0.9907 - recall: 0.9870 - val_loss: 0.1003 - val_accuracy: 0.9750 - val_precision: 1.0000 - val_recall: 0.9500
# Epoch 9/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0383 - accuracy: 0.9883 - precision: 0.9923 - recall: 0.9842 - val_loss: 0.0158 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 10/100
# 115/115 [==============================] - 10s 84ms/step - loss: 0.0290 - accuracy: 0.9913 - precision: 0.9924 - recall: 0.9902 - val_loss: 0.0382 - val_accuracy: 0.9913 - val_precision: 1.0000 - val_recall: 0.9826
# Epoch 11/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0197 - accuracy: 0.9932 - precision: 0.9946 - recall: 0.9918 - val_loss: 0.0141 - val_accuracy: 0.9967 - val_precision: 0.9957 - val_recall: 0.9978
# Epoch 12/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0158 - accuracy: 0.9951 - precision: 0.9956 - recall: 0.9946 - val_loss: 0.0417 - val_accuracy: 0.9859 - val_precision: 1.0000 - val_recall: 0.9717
# Epoch 13/100
# 115/115 [==============================] - 9s 78ms/step - loss: 0.0180 - accuracy: 0.9937 - precision: 0.9935 - recall: 0.9940 - val_loss: 0.1314 - val_accuracy: 0.9761 - val_precision: 1.0000 - val_recall: 0.9522
# Epoch 14/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0199 - accuracy: 0.9937 - precision: 0.9967 - recall: 0.9908 - val_loss: 0.0124 - val_accuracy: 0.9957 - val_precision: 0.9957 - val_recall: 0.9957
# Epoch 15/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0096 - accuracy: 0.9976 - precision: 0.9989 - recall: 0.9962 - val_loss: 0.0654 - val_accuracy: 0.9837 - val_precision: 1.0000 - val_recall: 0.9674
# Epoch 16/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0221 - accuracy: 0.9921 - precision: 0.9940 - recall: 0.9902 - val_loss: 0.0561 - val_accuracy: 0.9804 - val_precision: 0.9623 - val_recall: 1.0000
# Epoch 17/100
# 115/115 [==============================] - 17s 148ms/step - loss: 0.0179 - accuracy: 0.9954 - precision: 0.9962 - recall: 0.9946 - val_loss: 0.0101 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 18/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0234 - accuracy: 0.9924 - precision: 0.9935 - recall: 0.9913 - val_loss: 0.0424 - val_accuracy: 0.9783 - val_precision: 0.9603 - val_recall: 0.9978
# Epoch 19/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0106 - accuracy: 0.9965 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.0496 - val_accuracy: 0.9837 - val_precision: 0.9704 - val_recall: 0.9978
# Epoch 20/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0293 - accuracy: 0.9918 - precision: 0.9935 - recall: 0.9902 - val_loss: 0.0493 - val_accuracy: 0.9902 - val_precision: 1.0000 - val_recall: 0.9804
# Epoch 21/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0145 - accuracy: 0.9946 - precision: 0.9951 - recall: 0.9940 - val_loss: 0.0113 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 22/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0292 - accuracy: 0.9902 - precision: 0.9892 - recall: 0.9913 - val_loss: 0.0217 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 23/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0137 - accuracy: 0.9959 - precision: 0.9946 - recall: 0.9973 - val_loss: 0.0169 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 24/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0172 - accuracy: 0.9948 - precision: 0.9967 - recall: 0.9929 - val_loss: 0.0116 - val_accuracy: 0.9967 - val_precision: 0.9957 - val_recall: 0.9978
# Epoch 25/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0161 - accuracy: 0.9937 - precision: 0.9935 - recall: 0.9940 - val_loss: 0.0047 - val_accuracy: 0.9978 - val_precision: 0.9957 - val_recall: 1.0000
# Epoch 26/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0086 - accuracy: 0.9973 - precision: 0.9967 - recall: 0.9978 - val_loss: 0.0412 - val_accuracy: 0.9837 - val_precision: 0.9684 - val_recall: 1.0000
# Epoch 27/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0130 - accuracy: 0.9946 - precision: 0.9940 - recall: 0.9951 - val_loss: 0.0225 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 28/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0086 - accuracy: 0.9973 - precision: 0.9962 - recall: 0.9984 - val_loss: 0.0092 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 29/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0138 - accuracy: 0.9957 - precision: 0.9962 - recall: 0.9951 - val_loss: 0.0217 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 30/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0064 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0143 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 31/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0024 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9989 - val_loss: 0.0148 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 32/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0109 - accuracy: 0.9962 - precision: 0.9967 - recall: 0.9957 - val_loss: 0.0096 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 33/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0107 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.0092 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 34/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0033 - accuracy: 0.9984 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0409 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9848
# Epoch 35/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0034 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0277 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 36/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0081 - accuracy: 0.9973 - precision: 0.9978 - recall: 0.9967 - val_loss: 0.0047 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 37/100
# 115/115 [==============================] - 18s 155ms/step - loss: 0.0105 - accuracy: 0.9962 - precision: 0.9973 - recall: 0.9951 - val_loss: 0.0034 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 38/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0014 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 39/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0097 - accuracy: 0.9951 - precision: 0.9946 - recall: 0.9957 - val_loss: 0.0155 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 40/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0131 - accuracy: 0.9970 - precision: 0.9962 - recall: 0.9978 - val_loss: 0.0092 - val_accuracy: 0.9957 - val_precision: 0.9957 - val_recall: 0.9957
# Epoch 41/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0030 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0091 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 42/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0074 - accuracy: 0.9986 - precision: 0.9978 - recall: 0.9995 - val_loss: 0.0056 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 43/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0089 - accuracy: 0.9967 - precision: 0.9962 - recall: 0.9973 - val_loss: 0.0066 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 44/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0269 - accuracy: 0.9918 - precision: 0.9929 - recall: 0.9908 - val_loss: 0.3259 - val_accuracy: 0.8141 - val_precision: 0.7290 - val_recall: 1.0000
# Epoch 45/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0183 - accuracy: 0.9940 - precision: 0.9940 - recall: 0.9940 - val_loss: 0.0655 - val_accuracy: 0.9728 - val_precision: 0.9485 - val_recall: 1.0000
# Epoch 46/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0103 - accuracy: 0.9962 - precision: 0.9957 - recall: 0.9967 - val_loss: 0.0355 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9848
# Epoch 47/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0064 - accuracy: 0.9986 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0102 - val_accuracy: 0.9946 - val_precision: 0.9978 - val_recall: 0.9913
# Epoch 48/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0092 - accuracy: 0.9973 - precision: 0.9967 - recall: 0.9978 - val_loss: 0.0165 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 49/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0049 - accuracy: 0.9981 - precision: 0.9989 - recall: 0.9973 - val_loss: 0.0107 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 50/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0024 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0093 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 51/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0074 - accuracy: 0.9970 - precision: 0.9962 - recall: 0.9978 - val_loss: 0.0190 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 52/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0093 - accuracy: 0.9954 - precision: 0.9962 - recall: 0.9946 - val_loss: 0.0059 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 53/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0140 - accuracy: 0.9951 - precision: 0.9967 - recall: 0.9935 - val_loss: 0.0051 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 54/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0063 - accuracy: 0.9978 - precision: 0.9973 - recall: 0.9984 - val_loss: 0.0049 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 55/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0023 - accuracy: 0.9992 - precision: 1.0000 - recall: 0.9984 - val_loss: 0.0055 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 56/100
# 115/115 [==============================] - 9s 79ms/step - loss: 2.5487e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 57/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.8600e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 58/100
# 115/115 [==============================] - 9s 80ms/step - loss: 8.7616e-04 - accuracy: 0.9997 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 59/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0076 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0104 - val_accuracy: 0.9957 - val_precision: 0.9957 - val_recall: 0.9957
# Epoch 60/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0023 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0031 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 61/100
# 115/115 [==============================] - 9s 80ms/step - loss: 3.5172e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 62/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0158 - accuracy: 0.9951 - precision: 0.9956 - recall: 0.9946 - val_loss: 0.0315 - val_accuracy: 0.9913 - val_precision: 1.0000 - val_recall: 0.9826
# Epoch 63/100
# 115/115 [==============================] - 21s 186ms/step - loss: 0.0084 - accuracy: 0.9981 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0026 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 64/100
# 115/115 [==============================] - 9s 80ms/step - loss: 5.3146e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 65/100
# 115/115 [==============================] - 9s 80ms/step - loss: 9.6808e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 66/100
# 115/115 [==============================] - 9s 81ms/step - loss: 6.5475e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 67/100
# 115/115 [==============================] - 9s 81ms/step - loss: 3.5265e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 68/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0056 - accuracy: 0.9986 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0581 - val_accuracy: 0.9848 - val_precision: 0.9705 - val_recall: 1.0000
# Epoch 69/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0197 - accuracy: 0.9929 - precision: 0.9919 - recall: 0.9940 - val_loss: 0.0204 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 70/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0102 - accuracy: 0.9957 - precision: 0.9946 - recall: 0.9967 - val_loss: 0.0219 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 71/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0022 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0172 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 72/100
# 115/115 [==============================] - 9s 80ms/step - loss: 9.3368e-04 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0155 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 73/100
# 115/115 [==============================] - 9s 79ms/step - loss: 1.5988e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 74/100
# 115/115 [==============================] - 9s 79ms/step - loss: 1.1216e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 75/100
# 115/115 [==============================] - 9s 80ms/step - loss: 8.6831e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 76/100
# 115/115 [==============================] - 9s 81ms/step - loss: 8.6158e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 77/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0145 - accuracy: 0.9954 - precision: 0.9951 - recall: 0.9957 - val_loss: 0.0062 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 78/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0020 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.3407 - val_accuracy: 0.8826 - val_precision: 0.8099 - val_recall: 1.0000
# Epoch 79/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0033 - accuracy: 0.9981 - precision: 0.9984 - recall: 0.9978 - val_loss: 0.0014 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 80/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0070 - accuracy: 0.9981 - precision: 0.9984 - recall: 0.9978 - val_loss: 0.0394 - val_accuracy: 0.9837 - val_precision: 0.9684 - val_recall: 1.0000
# Epoch 81/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0045 - accuracy: 0.9984 - precision: 0.9978 - recall: 0.9989 - val_loss: 0.0049 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 82/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0070 - accuracy: 0.9970 - precision: 0.9973 - recall: 0.9967 - val_loss: 0.0106 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 83/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0250 - accuracy: 0.9927 - precision: 0.9935 - recall: 0.9918 - val_loss: 0.1488 - val_accuracy: 0.9293 - val_precision: 0.8776 - val_recall: 0.9978
# Epoch 84/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0169 - accuracy: 0.9943 - precision: 0.9951 - recall: 0.9935 - val_loss: 0.0246 - val_accuracy: 0.9935 - val_precision: 0.9871 - val_recall: 1.0000
# Epoch 85/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0028 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0060 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 86/100
# 115/115 [==============================] - 9s 79ms/step - loss: 9.3037e-04 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0069 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 87/100
# 115/115 [==============================] - 9s 80ms/step - loss: 7.4296e-04 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0214 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 88/100
# 115/115 [==============================] - 9s 80ms/step - loss: 6.5674e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 89/100
# 115/115 [==============================] - 9s 80ms/step - loss: 5.0253e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 90/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.2152e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 91/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.1999e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 92/100
# 115/115 [==============================] - 9s 79ms/step - loss: 1.8706e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 93/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.8141e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 94/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.2793e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9946 - val_precision: 0.9914 - val_recall: 0.9978
# Epoch 95/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0164 - accuracy: 0.9957 - precision: 0.9951 - recall: 0.9962 - val_loss: 0.0016 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 96/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0035 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0208 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 97/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0063 - accuracy: 0.9981 - precision: 0.9973 - recall: 0.9989 - val_loss: 0.0163 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 98/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0017 - accuracy: 0.9997 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 99/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.2701e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9989 - val_precision: 0.9978 - val_recall: 1.0000
# Epoch 100/100
# 115/115 [==============================] - 9s 80ms/step - loss: 9.8038e-04 - accuracy: 0.9997 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0026 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# model_Fold = 1 accuracy: 1.0
# model_Fold = 1 precision: 1.0
# model_Fold = 1 recall: 1.0
# model_Fold = 1 f1_score: 1.0
# X_train:  (3680, 178, 1)
# X_val:  (920, 178, 1)
# y_train:  (3680,)
# y_val:  (920,)
#
#
# ---- fold = 2 ------
#
# Epoch 1/100
# 115/115 [==============================] - 33s 180ms/step - loss: 0.1715 - accuracy: 0.9372 - precision: 0.9482 - recall: 0.9250 - val_loss: 8.9380 - val_accuracy: 0.5109 - val_precision: 0.5055 - val_recall: 1.0000
# Epoch 2/100
# 115/115 [==============================] - 12s 103ms/step - loss: 0.0837 - accuracy: 0.9723 - precision: 0.9780 - recall: 0.9663 - val_loss: 1.8545 - val_accuracy: 0.5946 - val_precision: 0.5522 - val_recall: 1.0000
# Epoch 3/100
# 115/115 [==============================] - 14s 125ms/step - loss: 0.0699 - accuracy: 0.9728 - precision: 0.9744 - recall: 0.9712 - val_loss: 0.7244 - val_accuracy: 0.6587 - val_precision: 0.5943 - val_recall: 1.0000
# Epoch 4/100
# 115/115 [==============================] - 15s 135ms/step - loss: 0.0651 - accuracy: 0.9777 - precision: 0.9782 - recall: 0.9772 - val_loss: 0.0615 - val_accuracy: 0.9793 - val_precision: 0.9662 - val_recall: 0.9935
# Epoch 5/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.0487 - accuracy: 0.9842 - precision: 0.9869 - recall: 0.9815 - val_loss: 0.0222 - val_accuracy: 0.9924 - val_precision: 0.9935 - val_recall: 0.9913
# Epoch 6/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0299 - accuracy: 0.9910 - precision: 0.9934 - recall: 0.9886 - val_loss: 0.0640 - val_accuracy: 0.9793 - val_precision: 1.0000 - val_recall: 0.9587
# Epoch 7/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0239 - accuracy: 0.9916 - precision: 0.9924 - recall: 0.9908 - val_loss: 0.9397 - val_accuracy: 0.6880 - val_precision: 0.6158 - val_recall: 1.0000
# Epoch 8/100
# 115/115 [==============================] - 17s 153ms/step - loss: 0.0322 - accuracy: 0.9872 - precision: 0.9864 - recall: 0.9880 - val_loss: 0.0271 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 9/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0388 - accuracy: 0.9870 - precision: 0.9918 - recall: 0.9821 - val_loss: 0.0389 - val_accuracy: 0.9859 - val_precision: 1.0000 - val_recall: 0.9717
# Epoch 10/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0267 - accuracy: 0.9899 - precision: 0.9886 - recall: 0.9913 - val_loss: 0.0529 - val_accuracy: 0.9859 - val_precision: 1.0000 - val_recall: 0.9717
# Epoch 11/100
# 115/115 [==============================] - 21s 181ms/step - loss: 0.0183 - accuracy: 0.9935 - precision: 0.9956 - recall: 0.9913 - val_loss: 0.0122 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 12/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0208 - accuracy: 0.9924 - precision: 0.9945 - recall: 0.9902 - val_loss: 0.0095 - val_accuracy: 0.9935 - val_precision: 0.9956 - val_recall: 0.9913
# Epoch 13/100
# 115/115 [==============================] - 10s 83ms/step - loss: 0.0185 - accuracy: 0.9935 - precision: 0.9946 - recall: 0.9924 - val_loss: 0.0173 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 14/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0467 - accuracy: 0.9842 - precision: 0.9864 - recall: 0.9821 - val_loss: 0.0244 - val_accuracy: 0.9924 - val_precision: 0.9978 - val_recall: 0.9870
# Epoch 15/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0366 - accuracy: 0.9867 - precision: 0.9907 - recall: 0.9826 - val_loss: 0.0295 - val_accuracy: 0.9891 - val_precision: 0.9808 - val_recall: 0.9978
# Epoch 16/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0177 - accuracy: 0.9940 - precision: 0.9956 - recall: 0.9924 - val_loss: 0.0163 - val_accuracy: 0.9946 - val_precision: 0.9935 - val_recall: 0.9957
# Epoch 17/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0281 - accuracy: 0.9913 - precision: 0.9940 - recall: 0.9886 - val_loss: 0.0286 - val_accuracy: 0.9957 - val_precision: 0.9957 - val_recall: 0.9957
# Epoch 18/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0321 - accuracy: 0.9899 - precision: 0.9902 - recall: 0.9897 - val_loss: 0.0157 - val_accuracy: 0.9957 - val_precision: 0.9935 - val_recall: 0.9978
# Epoch 19/100
# 115/115 [==============================] - 17s 151ms/step - loss: 0.0213 - accuracy: 0.9921 - precision: 0.9924 - recall: 0.9918 - val_loss: 0.0082 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 20/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0134 - accuracy: 0.9946 - precision: 0.9946 - recall: 0.9946 - val_loss: 0.0103 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 21/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0432 - accuracy: 0.9883 - precision: 0.9902 - recall: 0.9864 - val_loss: 1.0780 - val_accuracy: 0.7815 - val_precision: 0.6959 - val_recall: 1.0000
# Epoch 22/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0333 - accuracy: 0.9894 - precision: 0.9886 - recall: 0.9902 - val_loss: 0.1268 - val_accuracy: 0.9663 - val_precision: 1.0000 - val_recall: 0.9326
# Epoch 23/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0098 - accuracy: 0.9962 - precision: 0.9957 - recall: 0.9967 - val_loss: 0.0202 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 24/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0133 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - val_loss: 0.2089 - val_accuracy: 0.9065 - val_precision: 0.8425 - val_recall: 1.0000
# Epoch 25/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0199 - accuracy: 0.9940 - precision: 0.9924 - recall: 0.9957 - val_loss: 0.0194 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 26/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0134 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - val_loss: 0.0463 - val_accuracy: 0.9750 - val_precision: 0.9543 - val_recall: 0.9978
# Epoch 27/100
# 115/115 [==============================] - 19s 168ms/step - loss: 0.0085 - accuracy: 0.9965 - precision: 0.9962 - recall: 0.9967 - val_loss: 0.0045 - val_accuracy: 0.9989 - val_precision: 0.9978 - val_recall: 1.0000
# Epoch 28/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0156 - accuracy: 0.9946 - precision: 0.9946 - recall: 0.9946 - val_loss: 0.0143 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 29/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0119 - accuracy: 0.9948 - precision: 0.9924 - recall: 0.9973 - val_loss: 0.0380 - val_accuracy: 0.9848 - val_precision: 0.9705 - val_recall: 1.0000
# Epoch 30/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0089 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.0529 - val_accuracy: 0.9815 - val_precision: 0.9644 - val_recall: 1.0000
# Epoch 31/100
# 115/115 [==============================] - 9s 82ms/step - loss: 0.0047 - accuracy: 0.9989 - precision: 0.9995 - recall: 0.9984 - val_loss: 0.0500 - val_accuracy: 0.9815 - val_precision: 0.9663 - val_recall: 0.9978
# Epoch 32/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0055 - accuracy: 0.9984 - precision: 0.9978 - recall: 0.9989 - val_loss: 0.0223 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 33/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0105 - accuracy: 0.9959 - precision: 0.9962 - recall: 0.9957 - val_loss: 0.0056 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 34/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0082 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0100 - val_accuracy: 0.9967 - val_precision: 0.9935 - val_recall: 1.0000
# Epoch 35/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0044 - accuracy: 0.9981 - precision: 0.9984 - recall: 0.9978 - val_loss: 0.0147 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 36/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0039 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0270 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 37/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0080 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9978 - val_loss: 0.0176 - val_accuracy: 0.9935 - val_precision: 0.9892 - val_recall: 0.9978
# Epoch 38/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0024 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0188 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 39/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0031 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0336 - val_accuracy: 0.9859 - val_precision: 0.9765 - val_recall: 0.9957
# Epoch 40/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0175 - accuracy: 0.9954 - precision: 0.9951 - recall: 0.9957 - val_loss: 0.0590 - val_accuracy: 0.9880 - val_precision: 1.0000 - val_recall: 0.9761
# Epoch 41/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0296 - accuracy: 0.9899 - precision: 0.9902 - recall: 0.9897 - val_loss: 0.0225 - val_accuracy: 0.9946 - val_precision: 0.9914 - val_recall: 0.9978
# Epoch 42/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0142 - accuracy: 0.9948 - precision: 0.9962 - recall: 0.9935 - val_loss: 0.0083 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 43/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0059 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.1668 - val_accuracy: 0.9652 - val_precision: 1.0000 - val_recall: 0.9304
# Epoch 44/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0125 - accuracy: 0.9957 - precision: 0.9962 - recall: 0.9951 - val_loss: 0.0063 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 45/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0040 - accuracy: 0.9986 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0053 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 46/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0092 - accuracy: 0.9965 - precision: 0.9951 - recall: 0.9978 - val_loss: 0.0114 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 47/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0083 - accuracy: 0.9970 - precision: 0.9973 - recall: 0.9967 - val_loss: 0.0191 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 48/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0032 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0179 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 49/100
# 115/115 [==============================] - 9s 80ms/step - loss: 6.9917e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 50/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0175 - accuracy: 0.9932 - precision: 0.9935 - recall: 0.9929 - val_loss: 0.0217 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 51/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0029 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0432 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9848
# Epoch 52/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0107 - accuracy: 0.9965 - precision: 0.9962 - recall: 0.9967 - val_loss: 0.0180 - val_accuracy: 0.9946 - val_precision: 0.9978 - val_recall: 0.9913
# Epoch 53/100
# 115/115 [==============================] - 9s 81ms/step - loss: 6.1467e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 54/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0039 - accuracy: 0.9986 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0278 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 55/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0153 - accuracy: 0.9954 - precision: 0.9962 - recall: 0.9946 - val_loss: 0.0886 - val_accuracy: 0.9587 - val_precision: 0.9237 - val_recall: 1.0000
# Epoch 56/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0046 - accuracy: 0.9989 - precision: 0.9984 - recall: 0.9995 - val_loss: 0.0142 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 57/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.3387e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 58/100
# 115/115 [==============================] - 9s 81ms/step - loss: 8.9272e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 59/100
# 115/115 [==============================] - 9s 81ms/step - loss: 1.9878e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 60/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.0857e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 61/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0063 - accuracy: 0.9965 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.3467 - val_accuracy: 0.9000 - val_precision: 0.8333 - val_recall: 1.0000
# Epoch 62/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0207 - accuracy: 0.9921 - precision: 0.9913 - recall: 0.9929 - val_loss: 0.0238 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 63/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0049 - accuracy: 0.9976 - precision: 0.9984 - recall: 0.9967 - val_loss: 0.0103 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 64/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0101 - accuracy: 0.9978 - precision: 0.9962 - recall: 0.9995 - val_loss: 0.1419 - val_accuracy: 0.9663 - val_precision: 1.0000 - val_recall: 0.9326
# Epoch 65/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0318 - accuracy: 0.9905 - precision: 0.9908 - recall: 0.9902 - val_loss: 0.0257 - val_accuracy: 0.9913 - val_precision: 0.9850 - val_recall: 0.9978
# Epoch 66/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0037 - accuracy: 0.9984 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0106 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 67/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0067 - accuracy: 0.9981 - precision: 0.9984 - recall: 0.9978 - val_loss: 0.0180 - val_accuracy: 0.9957 - val_precision: 0.9978 - val_recall: 0.9935
# Epoch 68/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0105 - accuracy: 0.9965 - precision: 0.9967 - recall: 0.9962 - val_loss: 0.0309 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 69/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0056 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9978 - val_loss: 0.0355 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 70/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0054 - accuracy: 0.9976 - precision: 0.9978 - recall: 0.9973 - val_loss: 0.0118 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 71/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0099 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.0050 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 72/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0073 - accuracy: 0.9984 - precision: 0.9989 - recall: 0.9978 - val_loss: 0.0877 - val_accuracy: 0.9609 - val_precision: 0.9274 - val_recall: 1.0000
# Epoch 73/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0011 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9967 - val_precision: 0.9957 - val_recall: 0.9978
# Epoch 74/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.5398e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 75/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0034 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0143 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 76/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0026 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0119 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 77/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.9333e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 78/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0052 - accuracy: 0.9981 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0143 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 79/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0011 - accuracy: 0.9997 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 80/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0017 - accuracy: 0.9997 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9978 - val_precision: 0.9978 - val_recall: 0.9978
# Epoch 81/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.0341e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 82/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0193 - accuracy: 0.9937 - precision: 0.9924 - recall: 0.9951 - val_loss: 0.8406 - val_accuracy: 0.8098 - val_precision: 0.7244 - val_recall: 1.0000
# Epoch 83/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0055 - accuracy: 0.9978 - precision: 0.9973 - recall: 0.9984 - val_loss: 0.0978 - val_accuracy: 0.9848 - val_precision: 1.0000 - val_recall: 0.9696
# Epoch 84/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0075 - accuracy: 0.9962 - precision: 0.9957 - recall: 0.9967 - val_loss: 0.0062 - val_accuracy: 0.9957 - val_precision: 0.9957 - val_recall: 0.9957
# Epoch 85/100
# 115/115 [==============================] - 9s 80ms/step - loss: 6.6880e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9967 - val_precision: 0.9935 - val_recall: 1.0000
# Epoch 86/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0086 - accuracy: 0.9970 - precision: 0.9973 - recall: 0.9967 - val_loss: 0.0105 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 87/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0030 - accuracy: 0.9986 - precision: 0.9984 - recall: 0.9989 - val_loss: 0.0082 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 88/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0031 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0107 - val_accuracy: 0.9967 - val_precision: 0.9957 - val_recall: 0.9978
# Epoch 89/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0015 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0123 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9891
# Epoch 90/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.5041e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 91/100
# 115/115 [==============================] - 9s 80ms/step - loss: 8.8596e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 92/100
# 115/115 [==============================] - 9s 80ms/step - loss: 6.8255e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 93/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0034 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0977 - val_accuracy: 0.9793 - val_precision: 1.0000 - val_recall: 0.9587
# Epoch 94/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0015 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0020 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 95/100
# 115/115 [==============================] - 9s 80ms/step - loss: 9.4359e-04 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0099 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 96/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.8254e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 97/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.8995e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 98/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0087 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.0695 - val_accuracy: 0.9717 - val_precision: 0.9465 - val_recall: 1.0000
# Epoch 99/100
# 115/115 [==============================] - 9s 79ms/step - loss: 0.0035 - accuracy: 0.9984 - precision: 0.9995 - recall: 0.9973 - val_loss: 0.0104 - val_accuracy: 0.9967 - val_precision: 0.9978 - val_recall: 0.9957
# Epoch 100/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0016 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0514 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9848
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0045 - accuracy: 0.9989 - precision: 0.9978 - recall: 1.0000
# model_Fold = 2 accuracy: 0.998913049697876
# model_Fold = 2 precision: 0.9978308081626892
# model_Fold = 2 recall: 1.0
# model_Fold = 2 f1_score: 0.99891422645579
# X_train:  (3680, 178, 1)
# X_val:  (920, 178, 1)
# y_train:  (3680,)
# y_val:  (920,)
#
#
# ---- fold = 3 ------
#
# Epoch 1/100
# 115/115 [==============================] - 34s 182ms/step - loss: 0.1760 - accuracy: 0.9378 - precision: 0.9428 - recall: 0.9321 - val_loss: 10.3595 - val_accuracy: 0.6793 - val_precision: 0.6093 - val_recall: 1.0000
# Epoch 2/100
# 115/115 [==============================] - 10s 82ms/step - loss: 0.0866 - accuracy: 0.9690 - precision: 0.9716 - recall: 0.9663 - val_loss: 0.8710 - val_accuracy: 0.6087 - val_precision: 0.5611 - val_recall: 0.9978
# Epoch 3/100
# 115/115 [==============================] - 17s 153ms/step - loss: 0.0600 - accuracy: 0.9802 - precision: 0.9831 - recall: 0.9772 - val_loss: 0.5156 - val_accuracy: 0.7859 - val_precision: 0.7002 - val_recall: 1.0000
# Epoch 4/100
# 115/115 [==============================] - 15s 134ms/step - loss: 0.0457 - accuracy: 0.9848 - precision: 0.9906 - recall: 0.9788 - val_loss: 0.0652 - val_accuracy: 0.9707 - val_precision: 0.9482 - val_recall: 0.9957
# Epoch 5/100
# 115/115 [==============================] - 16s 135ms/step - loss: 0.0699 - accuracy: 0.9780 - precision: 0.9788 - recall: 0.9772 - val_loss: 0.0648 - val_accuracy: 0.9815 - val_precision: 0.9978 - val_recall: 0.9652
# Epoch 6/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0561 - accuracy: 0.9788 - precision: 0.9798 - recall: 0.9777 - val_loss: 0.0712 - val_accuracy: 0.9728 - val_precision: 0.9598 - val_recall: 0.9870
# Epoch 7/100
# ...
# Epoch 34/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0037 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 0.0053 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 35/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0019 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0045 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 36/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0193 - accuracy: 0.9932 - precision: 0.9956 - recall: 0.9908 - val_loss: 0.0097 - val_accuracy: 0.9978 - val_precision: 0.9957 - val_recall: 1.0000
# Epoch 37/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0058 - accuracy: 0.9981 - precision: 0.9989 - recall: 0.9973 - val_loss: 0.0147 - val_accuracy: 0.9946 - val_precision: 0.9892 - val_recall: 1.0000
# Epoch 38/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0068 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.0969 - val_accuracy: 0.9793 - val_precision: 1.0000 - val_recall: 0.9587
# Epoch 39/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0114 - accuracy: 0.9959 - precision: 0.9962 - recall: 0.9957 - val_loss: 0.0015 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 40/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0041 - accuracy: 0.9981 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0193 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 41/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0094 - accuracy: 0.9970 - precision: 0.9967 - recall: 0.9973 - val_loss: 0.0021 - val_accuracy: 0.9989 - val_precision: 0.9978 - val_recall: 1.0000
# Epoch 42/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0019 - accuracy: 0.9992 - precision: 0.9989 - recall: 0.9995 - val_loss: 8.2772e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 43/100
# 115/115 [==============================] - 9s 81ms/step - loss: 3.4194e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 44/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0041 - accuracy: 0.9984 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0633 - val_accuracy: 0.9793 - val_precision: 0.9603 - val_recall: 1.0000
# Epoch 45/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0174 - accuracy: 0.9937 - precision: 0.9940 - recall: 0.9935 - val_loss: 0.0085 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 46/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0066 - accuracy: 0.9981 - precision: 0.9978 - recall: 0.9984 - val_loss: 0.0090 - val_accuracy: 0.9967 - val_precision: 0.9935 - val_recall: 1.0000
# Epoch 47/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0114 - accuracy: 0.9970 - precision: 0.9978 - recall: 0.9962 - val_loss: 0.1832 - val_accuracy: 0.8967 - val_precision: 0.8288 - val_recall: 1.0000
# Epoch 48/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0019 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0015 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 49/100
# 115/115 [==============================] - 9s 80ms/step - loss: 7.7223e-04 - accuracy: 0.9997 - precision: 0.9995 - recall: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 50/100
# 115/115 [==============================] - 9s 80ms/step - loss: 6.8003e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 51/100
# 115/115 [==============================] - 9s 80ms/step - loss: 7.6470e-04 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 1.7211e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 52/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0233 - accuracy: 0.9927 - precision: 0.9924 - recall: 0.9929 - val_loss: 0.0506 - val_accuracy: 0.9739 - val_precision: 0.9504 - val_recall: 1.0000
# Epoch 53/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0100 - accuracy: 0.9970 - precision: 0.9967 - recall: 0.9973 - val_loss: 0.0038 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 54/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0051 - accuracy: 0.9984 - precision: 0.9989 - recall: 0.9978 - val_loss: 0.0047 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 55/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0110 - accuracy: 0.9957 - precision: 0.9973 - recall: 0.9940 - val_loss: 0.0047 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 56/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0101 - accuracy: 0.9978 - precision: 0.9984 - recall: 0.9973 - val_loss: 0.0033 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 57/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0042 - accuracy: 0.9989 - precision: 0.9995 - recall: 0.9984 - val_loss: 0.0033 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 58/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0055 - accuracy: 0.9986 - precision: 0.9989 - recall: 0.9984 - val_loss: 0.0035 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 59/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0169 - accuracy: 0.9946 - precision: 0.9940 - recall: 0.9951 - val_loss: 0.0022 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 60/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0111 - accuracy: 0.9973 - precision: 0.9978 - recall: 0.9967 - val_loss: 0.0067 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 61/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0023 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 0.0131 - val_accuracy: 0.9935 - val_precision: 1.0000 - val_recall: 0.9870
# Epoch 62/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0051 - accuracy: 0.9976 - precision: 0.9978 - recall: 0.9973 - val_loss: 0.1350 - val_accuracy: 0.9598 - val_precision: 0.9256 - val_recall: 1.0000
# Epoch 63/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0039 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0029 - val_accuracy: 0.9989 - val_precision: 1.0000 - val_recall: 0.9978
# Epoch 64/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0084 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - val_loss: 0.1108 - val_accuracy: 0.9533 - val_precision: 0.9145 - val_recall: 1.0000
# Epoch 65/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0136 - accuracy: 0.9959 - precision: 0.9962 - recall: 0.9957 - val_loss: 0.0081 - val_accuracy: 0.9978 - val_precision: 1.0000 - val_recall: 0.9957
# Epoch 66/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0068 - accuracy: 0.9973 - precision: 0.9978 - recall: 0.9967 - val_loss: 0.0083 - val_accuracy: 0.9967 - val_precision: 1.0000 - val_recall: 0.9935
# Epoch 67/100
# 115/115 [==============================] - 9s 80ms/step - loss: 9.6658e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 68/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.3738e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.0104e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 69/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0017 - accuracy: 0.9995 - precision: 0.9989 - recall: 1.0000 - val_loss: 4.6704e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 70/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0040 - accuracy: 0.9984 - precision: 0.9989 - recall: 0.9978 - val_loss: 2.3716e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 71/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0036 - accuracy: 0.9992 - precision: 0.9995 - recall: 0.9989 - val_loss: 5.7606e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 72/100
# 115/115 [==============================] - 9s 81ms/step - loss: 0.0011 - accuracy: 0.9995 - precision: 0.9989 - recall: 1.0000 - val_loss: 2.2403e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 73/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.7900e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.5103e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 74/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0028 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 7.1449e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 75/100
# 115/115 [==============================] - 9s 80ms/step - loss: 0.0016 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.0149 - val_accuracy: 0.9957 - val_precision: 1.0000 - val_recall: 0.9913
# Epoch 76/100
# 115/115 [==============================] - 9s 80ms/step - loss: 3.6936e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.4123e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 77/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.6298e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0929e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 78/100
# 115/115 [==============================] - 9s 81ms/step - loss: 4.3211e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6866e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 79/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.7068e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.9131e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 80/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.4172e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.7898e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 81/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.9831e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7903e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 82/100
# 115/115 [==============================] - 9s 79ms/step - loss: 1.8258e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9989 - val_precision: 0.9978 - val_recall: 1.0000
# Epoch 83/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.6447e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.2514e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 84/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.0238e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4129e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 85/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.0234e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.2465e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 86/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.3877e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.1276e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 87/100
# 115/115 [==============================] - 9s 80ms/step - loss: 5.5882e-07 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.1041e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 88/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.0615e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0118e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 89/100
# 115/115 [==============================] - 9s 80ms/step - loss: 9.1469e-07 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.9394e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 90/100
# 115/115 [==============================] - 9s 80ms/step - loss: 7.7439e-07 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0068e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 91/100
# 115/115 [==============================] - 9s 80ms/step - loss: 5.8818e-07 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.5476e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 92/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.0677e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.5857e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 93/100
# 115/115 [==============================] - 9s 80ms/step - loss: 4.4885e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.0567e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 94/100
# 115/115 [==============================] - 9s 81ms/step - loss: 1.6826e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.5056e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 95/100
# 115/115 [==============================] - 9s 81ms/step - loss: 1.1022e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.6090e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 96/100
# 115/115 [==============================] - 9s 80ms/step - loss: 6.3865e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 3.0776e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 97/100
# 115/115 [==============================] - 9s 80ms/step - loss: 6.5975e-07 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8837e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 98/100
# 115/115 [==============================] - 9s 81ms/step - loss: 6.0650e-07 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.1542e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 99/100
# 115/115 [==============================] - 9s 80ms/step - loss: 1.0895e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.5892e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 100/100
# 115/115 [==============================] - 9s 80ms/step - loss: 2.0117e-07 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.7505e-06 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0012 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# model_Fold = 5 accuracy: 1.0
# model_Fold = 5 precision: 1.0
# model_Fold = 5 recall: 1.0
# model_Fold = 5 f1_score: 1.0
# Mean Accuracy: 0.9995652198791504
# Mean Precision: 0.9991323232650757
# Mean Recall: 1.0
# Mean F1_Score: 0.9995659733351181
